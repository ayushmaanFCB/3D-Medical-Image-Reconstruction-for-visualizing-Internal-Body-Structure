# %% [markdown]
# <a href="https://colab.research.google.com/github/ayushmaanFCB/3D-Medical-Image-Reconstruction-for-visualizing-Internal-Body-Structure/blob/main/UNet3D%20-%20Vision%20Transformer%20Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tcia_utils pydicom monai pytorch_msssim
# Out:
# Requirement already satisfied: tcia_utils in /usr/local/lib/python3.10/dist-packages (2.4.5)
# Requirement already satisfied: pydicom in /usr/local/lib/python3.10/dist-packages (3.0.1)
# Requirement already satisfied: monai in /usr/local/lib/python3.10/dist-packages (1.3.2)
# Collecting pytorch_msssim
#   Downloading pytorch_msssim-1.0.0-py3-none-any.whl.metadata (8.0 kB)
# Requirement already satisfied: bs4 in /usr/local/lib/python3.10/dist-packages (from tcia_utils) (0.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from tcia_utils) (2.2.2)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from tcia_utils) (5.24.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from tcia_utils) (2.32.3)
# Requirement already satisfied: unidecode in /usr/local/lib/python3.10/dist-packages (from tcia_utils) (1.3.8)
# Requirement already satisfied: torch>=1.9 in /usr/local/lib/python3.10/dist-packages (from monai) (2.4.1+cu121)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from monai) (1.26.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->monai) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->monai) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->monai) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->monai) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->monai) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->monai) (2024.6.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from bs4->tcia_utils) (4.12.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->tcia_utils) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->tcia_utils) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->tcia_utils) (2024.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->tcia_utils) (9.0.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from plotly->tcia_utils) (24.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->tcia_utils) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->tcia_utils) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->tcia_utils) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->tcia_utils) (2024.8.30)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->tcia_utils) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->bs4->tcia_utils) (2.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.9->monai) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.9->monai) (1.3.0)
# Downloading pytorch_msssim-1.0.0-py3-none-any.whl (7.7 kB)
# Installing collected packages: pytorch_msssim
# Successfully installed pytorch_msssim-1.0.0

# %%
import requests
import pandas as pd
from tcia_utils import nbia

# %%
# get list of available collections as JSON
print(nbia.getCollections())
# Out:
# [{'Collection': '4D-Lung'}, {'Collection': 'ACRIN-6698'}, {'Collection': 'ACRIN-Contralateral-Breast-MR'}, {'Collection': 'ACRIN-FLT-Breast'}, {'Collection': 'ACRIN-NSCLC-FDG-PET'}, {'Collection': 'Adrenal-ACC-Ki67-Seg'}, {'Collection': 'Advanced-MRI-Breast-Lesions'}, {'Collection': 'Anti-PD-1_Lung'}, {'Collection': 'B-mode-and-CEUS-Liver'}, {'Collection': 'BREAST-DIAGNOSIS'}, {'Collection': 'Breast-Cancer-Screening-DBT'}, {'Collection': 'Breast-MRI-NACT-Pilot'}, {'Collection': 'C4KC-KiTS'}, {'Collection': 'CBIS-DDSM'}, {'Collection': 'CC-Radiomics-Phantom'}, {'Collection': 'CC-Radiomics-Phantom-2'}, {'Collection': 'CC-Radiomics-Phantom-3'}, {'Collection': 'CC-Tumor-Heterogeneity'}, {'Collection': 'CMB-AML'}, {'Collection': 'CMB-CRC'}, {'Collection': 'CMB-GEC'}, {'Collection': 'CMB-LCA'}, {'Collection': 'CMB-MEL'}, {'Collection': 'CMB-MML'}, {'Collection': 'CMB-PCA'}, {'Collection': 'CMMD'}, {'Collection': 'COVID-19-AR'}, {'Collection': 'COVID-19-NY-SBU'}, {'Collection': 'CPTAC-CCRCC'}, {'Collection': 'CPTAC-CM'}, {'Collection': 'CPTAC-LSCC'}, {'Collection': 'CPTAC-LUAD'}, {'Collection': 'CPTAC-PDA'}, {'Collection': 'CPTAC-SAR'}, {'Collection': 'CPTAC-UCEC'}, {'Collection': 'CT COLONOGRAPHY'}, {'Collection': 'CT Lymph Nodes'}, {'Collection': 'CT-Phantom4Radiomics'}, {'Collection': 'CT-vs-PET-Ventilation-Imaging'}, {'Collection': 'CTpred-Sunitinib-panNET'}, {'Collection': 'Colorectal-Liver-Metastases'}, {'Collection': 'DRO-Toolkit'}, {'Collection': 'Duke-Breast-Cancer-MRI'}, {'Collection': 'EA1141'}, {'Collection': 'GBM-DSC-MRI-DRO'}, {'Collection': 'HCC-TACE-Seg'}, {'Collection': 'ICDC-Glioma'}, {'Collection': 'ISPY1'}, {'Collection': 'ISPY2'}, {'Collection': 'LCTSC'}, {'Collection': 'LIDC-IDRI'}, {'Collection': 'Lung Phantom'}, {'Collection': 'Lung-Fused-CT-Pathology'}, {'Collection': 'Lung-PET-CT-Dx'}, {'Collection': 'LungCT-Diagnosis'}, {'Collection': 'MIDRC-RICORD-1A'}, {'Collection': 'MIDRC-RICORD-1B'}, {'Collection': 'MIDRC-RICORD-1C'}, {'Collection': 'Mediastinal-Lymph-Node-SEG'}, {'Collection': 'Mouse-Astrocytoma'}, {'Collection': 'Mouse-Mammary'}, {'Collection': 'NSCLC Radiogenomics'}, {'Collection': 'NSCLC-Radiomics'}, {'Collection': 'NSCLC-Radiomics-Genomics'}, {'Collection': 'NSCLC-Radiomics-Interobserver1'}, {'Collection': 'NaF PROSTATE'}, {'Collection': 'PDMR-292921-168-R'}, {'Collection': 'PDMR-425362-245-T'}, {'Collection': 'PDMR-521955-158-R4'}, {'Collection': 'PDMR-833975-119-R'}, {'Collection': 'PDMR-997537-175-T'}, {'Collection': 'PDMR-BL0293-F563'}, {'Collection': 'PDMR-Texture-Analysis'}, {'Collection': 'PROSTATE-DIAGNOSIS'}, {'Collection': 'PROSTATE-MRI'}, {'Collection': 'PROSTATEx'}, {'Collection': 'Pancreas-CT'}, {'Collection': 'Pancreatic-CT-CBCT-SEG'}, {'Collection': 'Pediatric-CT-SEG'}, {'Collection': 'Pelvic-Reference-Data'}, {'Collection': 'Phantom FDA'}, {'Collection': 'Prostate Fused-MRI-Pathology'}, {'Collection': 'Prostate-3T'}, {'Collection': 'Prostate-Anatomical-Edge-Cases'}, {'Collection': 'Prostate-MRI-US-Biopsy'}, {'Collection': 'Pseudo-PHI-DICOM-Data'}, {'Collection': 'QIBA CT-1C'}, {'Collection': 'QIBA-CT-Liver-Phantom'}, {'Collection': 'QIN Breast DCE-MRI'}, {'Collection': 'QIN LUNG CT'}, {'Collection': 'QIN PET Phantom'}, {'Collection': 'QIN-BREAST'}, {'Collection': 'QIN-PROSTATE-Repeatability'}, {'Collection': 'RIDER Breast MRI'}, {'Collection': 'RIDER Lung CT'}, {'Collection': 'RIDER Lung PET-CT'}, {'Collection': 'RIDER PHANTOM MRI'}, {'Collection': 'RIDER PHANTOM PET-CT'}, {'Collection': 'RIDER Pilot'}, {'Collection': 'ReMIND'}, {'Collection': 'SPIE-AAPM Lung CT Challenge'}, {'Collection': 'Soft-tissue-Sarcoma'}, {'Collection': 'Spine-Mets-CT-SEG'}, {'Collection': 'StageII-Colorectal-CT'}, {'Collection': 'TCGA-BLCA'}, {'Collection': 'TCGA-BRCA'}, {'Collection': 'TCGA-CESC'}, {'Collection': 'TCGA-COAD'}, {'Collection': 'TCGA-ESCA'}, {'Collection': 'TCGA-KICH'}, {'Collection': 'TCGA-KIRC'}, {'Collection': 'TCGA-KIRP'}, {'Collection': 'TCGA-LIHC'}, {'Collection': 'TCGA-LUAD'}, {'Colle ...

# %%
data = nbia.getSeries(collection = "Soft-tissue-Sarcoma")
data
# Out:
# [{'SeriesInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.104193299251798317056218297018',
#   'StudyInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.154535988064062152660648619556',
#   'Modality': 'MR',
#   'SeriesDate': '2003-12-12 00:00:00.0',
#   'SeriesDescription': '2. AXIAL T1 BOTH LEGS - RESEARCH',
#   'BodyPartExamined': 'EXTREMITY',
#   'SeriesNumber': 2,
#   'Collection': 'Soft-tissue-Sarcoma',
#   'PatientID': 'STS_010',
#   'Manufacturer': 'GE MEDICAL SYSTEMS',
#   'ManufacturerModelName': 'GENESIS_SIGNA',
#   'SoftwareVersions': '09',
#   'ImageCount': 48,
#   'TimeStamp': '2015-05-27 17:12:21.0',
#   'LicenseName': 'Creative Commons Attribution 3.0 Unported License',
#   'LicenseURI': 'http://creativecommons.org/licenses/by/3.0/',
#   'CollectionURI': 'https://doi.org/10.7937/K9/TCIA.2015.7GO2GSKS',
#   'FileSize': 25273786,
#   'DateReleased': '2015-05-27 17:12:21.0',
#   'StudyDesc': 'MRI LT LEG +C',
#   'StudyDate': '2003-12-12 00:00:00.0'},
#  {'SeriesInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.614409775072665417753627581100',
#   'StudyInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.154535988064062152660648619556',
#   'Modality': 'MR',
#   'SeriesDate': '2003-12-12 00:00:00.0',
#   'SeriesDescription': '3. AXIAL STIR - RESEARCH',
#   'BodyPartExamined': 'EXTREMITY',
#   'SeriesNumber': 3,
#   'Collection': 'Soft-tissue-Sarcoma',
#   'PatientID': 'STS_010',
#   'Manufacturer': 'GE MEDICAL SYSTEMS',
#   'ManufacturerModelName': 'GENESIS_SIGNA',
#   'SoftwareVersions': '09',
#   'ImageCount': 48,
#   'TimeStamp': '2015-05-27 17:12:06.0',
#   'LicenseName': 'Creative Commons Attribution 3.0 Unported License',
#   'LicenseURI': 'http://creativecommons.org/licenses/by/3.0/',
#   'CollectionURI': 'https://doi.org/10.7937/K9/TCIA.2015.7GO2GSKS',
#   'FileSize': 25273674,
#   'DateReleased': '2015-05-27 17:12:06.0',
#   'StudyDesc': 'MRI LT LEG +C',
#   'StudyDate': '2003-12-12 00:00:00.0'},
#  {'SeriesInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.125236013959219285601516346712',
#   'StudyInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.135795221898471481596787080639',
#   'Modality': 'MR',
#   'SeriesDate': '2005-01-07 00:00:00.0',
#   'SeriesDescription': '4. AXIAL  T1',
#   'BodyPartExamined': 'EXTREMITY',
#   'SeriesNumber': 4,
#   'Collection': 'Soft-tissue-Sarcoma',
#   'PatientID': 'STS_012',
#   'Manufacturer': 'GE MEDICAL SYSTEMS',
#   'ManufacturerModelName': 'GENESIS_SIGNA',
#   'SoftwareVersions': '09',
#   'ImageCount': 50,
#   'TimeStamp': '2015-05-27 17:12:34.0',
#   'LicenseName': 'Creative Commons Attribution 3.0 Unported License',
#   'LicenseURI': 'http://creativecommons.org/licenses/by/3.0/',
#   'CollectionURI': 'https://doi.org/10.7937/K9/TCIA.2015.7GO2GSKS',
#   'FileSize': 6664860,
#   'DateReleased': '2015-05-27 17:12:34.0',
#   'StudyDesc': 'MRI RT THIGH +C',
#   'StudyDate': '2005-01-07 00:00:00.0'},
#  {'SeriesInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.216398125896037785163292266798',
#   'StudyInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.135795221898471481596787080639',
#   'Modality': 'MR',
#   'SeriesDate': '2005-01-07 00:00:00.0',
#   'SeriesDescription': '5. AXIAL T2 F.S.',
#   'BodyPartExamined': 'EXTREMITY',
#   'SeriesNumber': 5,
#   'Collection': 'Soft-tissue-Sarcoma',
#   'PatientID': 'STS_012',
#   'Manufacturer': 'GE MEDICAL SYSTEMS',
#   'ManufacturerModelName': 'GENESIS_SIGNA',
#   'SoftwareVersions': '09',
#   'ImageCount': 50,
#   'TimeStamp': '2015-05-27 17:12:48.0',
#   'LicenseName': 'Creative Commons Attribution 3.0 Unported License',
#   'LicenseURI': 'http://creativecommons.org/licenses/by/3.0/',
#   'CollectionURI': 'https://doi.org/10.7937/K9/TCIA.2015.7GO2GSKS',
#   'FileSize': 26326632,
#   'DateReleased': '2015-05-27 17:12:48.0',
#   'StudyDesc': 'MRI RT THIGH +C',
#   'StudyDate': '2005-01-07 00:00:00.0'},
#  {'SeriesInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.246858556033491753396338124091',
#   'StudyInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.138880898825684937662553234096',
#   'Modality': 'MR',
#   'SeriesDate': '2000-12-07 00:00:00.0',
#   'SeriesDescription': '2- AXIAL T1 - RESEARCH',
#   'BodyPartExamined': 'EXTREMITY',
#   'SeriesNumber': 6,
#   'Collection': 'Soft-tissue-Sarcoma',
#   'PatientID': 'STS_045',
#   'Manufacturer': 'GE MEDICAL SYSTEMS',
#   'ManufacturerModelName': 'GENESIS_SIGNA',
#   'SoftwareVersions': '09',
#   'ImageCount': 45,
#   'TimeStamp': '2015-05-27 17:12:56.0',
#   'LicenseName': 'Creative Commons Attribution 3.0 Unported License',
#   'LicenseURI': 'http://creativecommons.org/licenses/by/3.0/',
#   'CollectionURI': 'https://doi.org/10.7937/K9/TCIA.2015.7GO2GSKS',
#   'FileSize': 23696040,
#   'DateReleased': '2015-05-27 17:12:56.0',
#   'StudyDesc': 'e+1 HANCHE GAUCHE C+',
#   'StudyDate': '2000-12-07 00:00:00.0'},
#  {'SeriesInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.192450855134954778311878585179',
#   'StudyInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.138880898825684937662553234096',
#   'Modality': 'MR',
#   'SeriesDate': '2000-12-07 00:00:00.0',
#   'SeriesDescription': '3- O-AXI FAT T2 - RESEARCH',
#   'BodyPartExamined': 'EXTREMITY',
#   'SeriesNumber': 5,
#   'Collection': 'Soft-tissue-Sarcoma',
#   'PatientID': 'STS_045',
#   'Manufacturer': 'GE MEDICAL SYSTEMS',
#   'ManufacturerModelName': 'GENESIS_SIGNA',
#   'SoftwareVersions': '09',
#   'ImageCount': 45,
#   'TimeStamp': '2015-05-27 17:13:10.0',
#   'LicenseName': 'Creative Commons Attribution 3.0 Unported License',
#   'LicenseURI': 'http://creativecommons.org/licenses/by/3.0/',
#   'CollectionURI': 'https://doi.org/10.7937/K9/TCIA.2015.7GO2GSKS',
#   'FileSize': 23696220,
#   'DateReleased': '2015-05-27 17:13:10.0',
#   'StudyDesc': 'e+1 HANCHE GAUCHE C+',
#   'StudyDate': '2000-12-07 00:00:00.0'},
#  {'SeriesInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.111743821765670568300320340756',
#   'StudyInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.224608962105781194201479494418',
#   'Modality': 'MR',
#   'SeriesDate': '2005-05-29 00:00:00.0',
#   'SeriesDescription': 'AXIALT1',
#   'BodyPartExamined': 'EXTREMITY',
#   'SeriesNumber': 3,
#   'Collection': 'Soft-tissue-Sarcoma',
#   'PatientID': 'STS_005',
#   'Manufacturer': 'GE MEDICAL SYSTEMS',
#   'ManufacturerModelName': 'GENESIS_SIGNA',
#   'SoftwareVersions': '09',
#   'ImageCount': 33,
#   'TimeStamp': '2015-05-27 17:13:17.0',
#   'LicenseName': 'Creative Commons Attribution 3.0 Unported License',
#   'LicenseURI': 'http://creativecommons.org/licenses/by/3.0/',
#   'CollectionURI': 'https://doi.org/10.7937/K9/TCIA.2015.7GO2GSKS',
#   'FileSize': 17376310,
#   'DateReleased': '2015-05-27 17:13:17.0',
#   'StudyDesc': 'IRM BRAS GAUCHE C-C+',
#   'StudyDate': '2005-05-29 00:00:00.0'},
#  {'SeriesInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.144488481585450606135009119508',
#   'StudyInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.224608962105781194201479494418',
#   'Modality': 'MR',
#   'SeriesDate': '2005-05-29 00:00:00.0',
#   'SeriesDescription': 'AXIALT2 FSE FS',
#   'BodyPartExamined': 'EXTREMITY',
#   'SeriesNumber': 5,
#   'Collection': 'Soft-tissue-Sarcoma',
#   'PatientID': 'STS_005',
#   'Manufacturer': 'GE MEDICAL SYSTEMS',
#   'ManufacturerModelName': 'GENESIS_SIGNA',
#   'SoftwareVersions': '09',
#   'ImageCount': 33,
#   'TimeStamp': '2015-05-27 17:13:24.0',
#   'LicenseName': 'Creative Commons Attribution 3.0 Unported License',
#   'LicenseURI': 'http://creativecommons.org/licenses/by/3.0/',
#   'CollectionURI': 'https://doi.org/10.7937/K9/TCIA.2015.7GO2GSKS',
#   'FileSize': 17376506,
#   'DateReleased': '2015-05-27 17:13:24.0',
#   'StudyDesc': 'IRM BRAS GAUCHE C-C+',
#   'StudyDate': '2005-05-29 00:00:00.0'},
#  {'SeriesInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.416620632851615222270746812831',
#   'StudyInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.235629096015019691049111996241',
#   'Modality': 'MR',
#   'SeriesDate': '2001-11-01 00:00:00.0',
#   'SeriesDescription': 'AX. T1 SE - RESEARCH',
#   'BodyPartExamined': 'EXTREMITY',
#   'SeriesNumber': 4,
#   'Collection': 'Soft-tissue-Sarcoma',
#   'PatientID': 'STS_006',
#   'Manufacturer': 'GE MEDICAL SYSTEMS',
#   'ManufacturerModelName': 'SIGNA EXCITE',
#   'SoftwareVersions': '11',
#   'ImageCount': 44,
#   'TimeStamp': '2015-05-27 17:59:55.0',
#   'LicenseName': 'Creative Commons Attribution 3.0 Unported License',
#   'LicenseURI': 'http://creativecommons.org/licenses/by/3.0/',
#   'CollectionURI': 'https://doi.org/10.7937/K9/TCIA.2015.7GO2GSKS',
#   'FileSize': 5866832,
#   'DateReleased': '2015-05-27 17:59:55.0',
#   'StudyDesc': 'MSK - Thigh (C+)',
#   'StudyDate': '2001-11-01 00:00:00.0'},
#  {'SeriesInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.211941179244652413817807880192',
#   'StudyInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.235629096015019691049111996241',
#   'Modality': 'MR',
#   'SeriesDate': '2001-11-01 00:00:00.0',
#   'SeriesDescription': 'AX. T2 FSE  FS - RESEARCH',
#   'BodyPartExamined': 'EXTREMITY',
#   'SeriesNumber': 5,
#   'Collection': 'Soft-tissue-Sarcoma',
#   'PatientID': 'STS_006',
#   'Manufacturer': 'GE MEDICAL SYSTEMS',
#   'ManufacturerModelName': 'SIGNA EXCITE',
#   'SoftwareVersions': '11',
#   'ImageCount': 44,
#   'TimeStamp': '2015-05-27 18:00:02.0',
#   'LicenseName': 'Creative Commons Attribution 3.0 Unported License',
#   'LicenseURI': 'http://creativecommons.org/licenses/by/3.0/',
#   'CollectionURI': 'https://doi.org/10.7937/K9/TCIA.2015.7GO2GSKS',
#   'FileSize': 5867184,
#   'DateReleased': '2015-05-27 18:00:02.0',
#   'StudyDesc': 'MSK - Thigh (C+)',
#   'StudyDate': '2001-11-01 00:00:00.0'},
#  {'SeriesInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.141913425836667824902104751633',
#   'StudyInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.164831775771577212153159002560',
#   'Modality': 'MR',
#   'SeriesDate': '2001-01-25 00:00:00.0',
#   'SeriesDescription': 'AX. T1 SE - RESEARCH',
#   'BodyPartExamined': 'EXTREMITY',
#   'SeriesNumber': 2,
#   'Collection': 'Soft-tissue-Sarcoma',
#   'PatientID': 'STS_044',
#   'Manufacturer': 'GE MEDICAL SYSTEMS',
#   'ManufacturerModelName': 'SIGNA EXCITE',
#   'SoftwareVersions': '11',
#   'ImageCount': 69,
#   'TimeStamp': '2015-05-27 18:00:15.0',
#   'LicenseName': 'Creative Commons Attribution 3.0 Unported License',
#   'LicenseURI': 'http://creativecommons.org/licenses/by/3.0/',
#   'CollectionURI': 'https://doi.org/10.7937/K9/TCIA.2015.7GO2GSKS',
#   'FileSize': 9197656,
#   'DateReleased': '2015-05-27 18:00:15.0',
#   'StudyDesc': 'MSK - Thigh (C+)',
#   'StudyDate': '2001-01-25 00:00:00.0'},
#  {'SeriesInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.336259625465633962775202385530',
#   'StudyInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.164831775771577212153159002560',
#   'Modality': 'MR',
#   'SeriesDate': '2001-01-25 00:00:00.0',
#   'SeriesDescription': 'AX. T2 FSE FS - RESEARCH',
#   'BodyPartExamined': 'EXTREMITY',
#   'SeriesNumber': 3,
#   'Collection': 'Soft-tissue-Sarcoma',
#   'PatientID': 'STS_044',
#   'Manufacturer': 'GE MEDICAL SYSTEMS',
#   'ManufacturerModelName': 'SIGNA EXCITE',
#   'SoftwareVersions': '11',
#   'ImageCount': 69,
#   'TimeStamp': '2015-05-27 18:00:23.0',
#   'LicenseName': 'Creative Commons Attribution 3.0 Unported License',
#   'LicenseURI': 'http://creativecommons.org/licenses/by/3.0/',
#   'CollectionURI': 'https://doi.org/10.7937/K9/TCIA.2015.7GO2GSKS',
#   'FileSize': 9197910,
#   'DateReleased': '2015-05-27 18:00:23.0',
#   'StudyDesc': 'MSK - Thigh (C+)',
#   'StudyDate': '2001-01-25 00:00:00.0'},
#  {'SeriesInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.329350639502440072042757623849',
#   'StudyInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.174115720031352334072955631859',
#   'Modality': 'MR',
#   'SeriesDate': '1999-10-03 00:00:00.0',
#   'SeriesDescription': 'Axial T1 ONLY TUMOR - RESEARCH',
#   'BodyPartExamined': 'EXTREMITY',
#   'SeriesNumber': 8,
#   'Collection': 'Soft-tissue-Sarcoma',
#   'PatientID': 'STS_032',
#   'Manufacturer': 'GE MEDICAL SYSTEMS',
#   'ManufacturerModelName': 'SIGNA EXCITE',
#   'SoftwareVersions': '11',
#   'ImageCount': 24,
#   'TimeStamp': '2015-05-27 18:00:31.0',
#   'LicenseName': 'Creative Commons Attribution 3.0 Unported License',
#   'LicenseURI': 'http://creativecommons.org/licenses/by/3.0/',
#   'CollectionURI': 'https://doi.org/10.7937/K9/TCIA.2015.7GO2GSKS',
#   'FileSize': 12637194,
#   'DateReleased': '2015-05-27 18:00:31.0',
#   'StudyDesc': 'B MRI-RT THIGH',
#   'StudyDate': '1999-10-03 00:00:00.0'},
#  {'SeriesInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.239973625803147462014340519229',
#   'StudyInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.174115720031352334072955631859',
#   'Modality': 'MR',
#   'SeriesDate': '1999-10-03 00:00:00.0',
#   'SeriesDescription': 'Axial FSE/T2 FS ONLY TUMOR - RESEARCH',
#   'BodyPartExamined': 'EXTREMITY',
#   'SeriesNumber': 10,
#   'Collection': 'Soft-tissue-Sarcoma',
#   'PatientID': 'STS_032',
#   'Manufacturer': 'GE MEDICAL SYSTEMS',
#   'ManufacturerModelName': 'SIGNA EXCITE',
#   'SoftwareVersions': '11',
#   'ImageCount': 24,
#   'TimeStamp': '2015-05-27 18:00:37.0',
#   'LicenseName': 'Creative Commons Attribution 3.0 Unported License',
#   'LicenseURI': 'http://creativecommons.org/licenses/by/3.0/',
#   'CollectionURI': 'https://doi.org/10.7937/K9/TCIA.2015.7GO2GSKS',
#   'FileSize': 12637386,
#   'DateReleased': '2015-05-27 18:00:37.0',
#   'StudyDesc': 'B MRI-RT THIGH',
#   'StudyDate': '1999-10-03 00:00:00.0'},
#  {'SeriesInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.103814160129376112983160841229',
#   'StudyInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.151571359487941069374230211999',
#   'Modality': 'MR',
#   'SeriesDate': '1999-07-04 00:00:00.0',
#   'SeriesDescription': 'AXIAL T1 - RESEARCH',
#   'BodyPartExamined': 'EXTREMITY',
#   'SeriesNumber': 4,
#   'Collection': 'Soft-tissue-Sarcoma',
#   'PatientID': 'STS_036',
#   'Manufacturer': 'GE MEDICAL SYSTEMS',
#   'ManufacturerModelName': 'SIGNA EXCITE',
#   'SoftwareVersions': '11',
#   'ImageCount': 44,
#   'TimeStamp': '2015-05-27 18:00:45.0',
#   'LicenseName': 'Creative Commons Attribution 3.0 Unported License',
#   'LicenseURI': 'http://creativecommons.org/licenses/by/3.0/',
#   'CollectionURI': 'https://doi.org/10.7937/K9/TCIA.2015.7GO2GSKS',
#   'FileSize': 23166690,
#   'DateReleased': '2015-05-27 18:00:45.0',
#   'StudyDesc': 'B MRI-PELVIS',
#   'StudyDate': '1999-07-04 00:00:00.0'},
#  {'SeriesInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.300161246843602623520691755268',
#   'StudyInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.151571359487941069374230211999',
#   'Modality': 'MR',
#   'SeriesDate': '1999-07-04 00:00:00.0',
#   'SeriesDescription': 'AXIAL FSE T2 - RESEARCH',
#   'BodyPartExamined': 'EXTREMITY',
#   'SeriesNumber': 5,
#   'Collection': 'Soft-tissue-Sarcoma',
#   'PatientID': 'STS_036',
#   'Manufacturer': 'GE MEDICAL SYSTEMS',
#   'ManufacturerModelName': 'SIGNA EXCITE',
#   'SoftwareVersions': '11',
#   'ImageCount': 44,
#   'TimeStamp': '2015-05-27 18:00:58.0',
#   'LicenseName': 'Creative Commons Attribution 3.0 Unported License',
#   'LicenseURI': 'http://creativecommons.org/licenses/by/3.0/',
#   'CollectionURI': 'https://doi.org/10.7937/K9/TCIA.2015.7GO2GSKS',
#   'FileSize': 23166866,
#   'DateReleased': '2015-05-27 18:00:58.0',
#   'StudyDesc': 'B MRI-PELVIS',
#   'StudyDate': '1999-07-04 00:00:00.0'},
#  {'SeriesInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.426189249282117680144490872363',
#   'StudyInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.226512162619941362079506989655',
#   'Modality': 'MR',
#   'SeriesDate': '2000-05-05 00:00:00.0',
#   'SeriesDescription': '2-AX  Stir irFSE H  DRT - RESEARCH',
#   'BodyPartExamined': 'EXTREMITY',
#   'SeriesNumber': 3,
#   'Collection': 'Soft-tissue-Sarcoma',
#   'PatientID': 'STS_040',
#   'Manufacturer': 'GE MEDICAL SYSTEMS',
#   'ManufacturerModelName': 'SIGNA EXCITE',
#   'SoftwareVersions': '11',
#   'ImageCount': 24,
#   'TimeStamp': '2015-05-27 18:01:05.0',
#   'LicenseName': 'Creative Commons Attribution 3.0 Unported License',
#   'LicenseURI': 'http://creativecommons.org/licenses/by/3.0/',
#   'CollectionURI': 'https://doi.org/10.7937/K9/TCIA.2015.7GO2GSKS',
#   'FileSize': 12638054,
#   'DateReleased': '2015-05-27 18:01:05.0',
#   'StudyDesc': 'IRM HANCHE DROITE C+',
#   'StudyDate': '2000-05-05 00:00:00.0'},
#  {'SeriesInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.148914696969002050713516731770',
#   'StudyInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.226512162619941362079506989655',
#   'Modality': 'MR',
#   'SeriesDate': '2000-05-05 00:00:00.0',
#   'SeriesDescription': '3-AX  T1 SE DRT - RESEARCH',
#   'BodyPartExamined': 'EXTREMITY',
#   'SeriesNumber': 2,
#   'Collection': 'Soft-tissue-Sarcoma',
#   'PatientID': 'STS_040',
#   'Manufacturer': 'GE MEDICAL SYSTEMS',
#   'ManufacturerModelName': 'SIGNA EXCITE',
#   'SoftwareVersions': '11',
#   'ImageCount': 24,
#   'TimeStamp': '2015-05-27 18:01:06.0',
#   'LicenseName': 'Creative Commons Attribution 3.0 Unported License',
#   'LicenseURI': 'http://creativecommons.org/licenses/by/3.0/',
#   'CollectionURI': 'https://doi.org/10.7937/K9/TCIA.2015.7GO2GSKS',
#   'FileSize': 12637718,
#   'DateReleased': '2015-05-27 18:01:06.0',
#   'StudyDesc': 'IRM HANCHE DROITE C+',
#   'StudyDate': '2000-05-05 00:00:00.0'},
#  {'SeriesInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.292858446636552191351331058403',
#   'StudyInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.131104785401186633385777573575',
#   'Modality': 'MR',
#   'SeriesDate': '1999-10-24 00:00:00.0',
#   'SeriesDescription': 'AXIAL  T1- RESEARCH',
#   'BodyPartExamined': 'EXTREMITY',
#   'SeriesNumber': 5,
#   'Collection': 'Soft-tissue-Sarcoma',
#   'PatientID': 'STS_051',
#   'Manufacturer': 'GE MEDICAL SYSTEMS',
#   'ManufacturerModelName': 'SIGNA EXCITE',
#   'SoftwareVersions': '11',
#   'ImageCount': 48,
#   'TimeStamp': '2015-05-27 18:01:19.0',
#   'LicenseName': 'Creative Commons Attribution 3.0 Unported License',
#   'LicenseURI': 'http://creativecommons.org/licenses/by/3.0/',
#   'CollectionURI': 'https://doi.org/10.7937/K9/TCIA.2015.7GO2GSKS',
#   'FileSize': 6398528,
#   'DateReleased': '2015-05-27 18:01:19.0',
#   'StudyDesc': 'B MRI-LT KNEE',
#   'StudyDate': '1999-10-24 00:00:00.0'},
#  {'SeriesInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.149458915691031472499901590143',
#   'StudyInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.131104785401186633385777573575',
#   'Modality': 'MR',
#   'SeriesDate': '1999-10-24 00:00:00.0',
#   'SeriesDescription': 'AXIAL  FSE T2 FATSAT - RESEARCH',
#   'BodyPartExamined': 'EXTREMITY',
#   'SeriesNumber': 6,
#   'Collection': 'Soft-tissue-Sarcoma',
#   'PatientID': 'STS_051',
#   'Manufacturer': 'GE MEDICAL SYSTEMS',
#   'ManufacturerModelName': 'SIGNA EXCITE',
#   'SoftwareVersions': '11',
#   'ImageCount': 48,
#   'TimeStamp': '2015-05-27 18:01:26.0',
#   'LicenseName': 'Creative Commons Attribution 3.0 Unported License',
#   'LicenseURI': 'http://creativecommons.org/licenses/by/3.0/',
#   'CollectionURI': 'https://doi.org/10.7937/K9/TCIA.2015.7GO2GSKS',
#   'FileSize': 6399104,
#   'DateReleased': '2015-05-27 18:01:26.0',
#   'StudyDesc': 'B MRI-LT KNEE',
#   'StudyDate': '1999-10-24 00:00:00.0'},
#  {'SeriesInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.261658826055074955516950744155',
#   'StudyInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.181126841199458877802601213878',
#   'Modality': 'MR',
#   'SeriesDate': '2004-03-10 00:00:00.0',
#   'SeriesDescription': 'AX STIR iPAT - RESEARCH',
#   'BodyPartExamined': 'EXTREMITY',
#   'SeriesNumber': 8,
#   'Collection': 'Soft-tissue-Sarcoma',
#   'PatientID': 'STS_016',
#   'Manufacturer': 'SIEMENS',
#   'ManufacturerModelName': 'Avanto',
#   'SoftwareVersions': 'syngo MR B15',
#   'ImageCount': 21,
#   'TimeStamp': '2015-05-27 17:53:23.0',
#   'LicenseName': 'Creative Commons Attribution 3.0 Unported License',
#   'LicenseURI': 'http://creativecommons.org/licenses/by/3.0/',
#   'CollectionURI': 'https://doi.org/10.7937/K9/TCIA.2015.7GO2GSKS',
#   'FileSize': 4691990,
#   'DateReleased': '2015-05-27 17:53:23.0',
#   'StudyDesc': 'IRM FEMUR/CUISSE GAUCHE C- C+',
#   'StudyDate': '2004-03-10 00:00:00.0'},
#  {'SeriesInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.970033975085870887235847474245',
#   'StudyInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.181126841199458877802601213878',
#   'Modality': 'MR',
#   'SeriesDate': '2004-03-10 00:00:00.0',
#   'SeriesDescription': 'AX TSE T1 IPAT - RESEARCH',
#   'BodyPartExamined': 'EXTREMITY',
#   'SeriesNumber': 9,
#   'Collection': 'Soft-tissue-Sarcoma',
#   'PatientID': 'STS_016',
#   'Manufacturer': 'SIEMENS',
#   'ManufacturerModelName': 'Avanto',
#   'SoftwareVersions': 'syngo MR B15',
#   'ImageCount': 21,
#   'TimeStamp': '2015-05-27 17:53:29.0',
#   'LicenseName': 'Creative Commons Attribution 3.0 Unported License',
#   'LicenseURI': 'http://creativecommons.org/licenses/by/3.0/',
#   'CollectionURI': 'https://doi.org/10.7937/K9/TCIA.2015.7GO2GSKS',
#   'FileSize': 11057006,
#   'DateReleased': '2015-05-27 17:53:29.0',
#   'StudyDesc': 'IRM FEMUR/CUISSE GAUCHE C- C+',
#   'StudyDate': '2004-03-10 00:00:00.0'},
#  {'SeriesInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.547952814730460769233389637595',
#   'StudyInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.211659248655092231923007628034',
#   'Modality': 'MR',
#   'SeriesDate': '2005-09-24 00:00:00.0',
#   'SeriesDescription': 'Sagittal T1',
#   'BodyPartExamined': 'EXTREMITY',
#   'SeriesNumber': 13,
#   'Collection': 'Soft-tissue-Sarcoma',
#   'PatientID': 'STS_011',
#   'Manufacturer': 'GE MEDICAL SYSTEMS',
#   'ManufacturerModelName': 'SIGNA EXCITE',
#   'ImageCount': 28,
#   'TimeStamp': '2015-05-27 17:41:06.0',
#   'LicenseName': 'Creative Commons Attribution 3.0 Unported License',
#   'LicenseURI': 'http://creativecommons.org/licenses/by/3.0/',
#   'CollectionURI': 'https://doi.org/10.7937/K9/TCIA.2015.7GO2GSKS',
#   'FileSize': 14742954,
#   'DateReleased': '2015-05-27 17:41:06.0',
#   'StudyDesc': 'MRI RT THIGH',
#   'StudyDate': '2005-09-24 00:00:00.0'},
#  {'SeriesInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.275802542059021701449696303567',
#   'StudyInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.211659248655092231923007628034',
#   'Modality': 'MR',
#   'SeriesDate': '2005-09-24 00:00:00.0',
#   'SeriesDescription': 'sag FSE/T2 Fatsat',
#   'BodyPartExamined': 'EXTREMITY',
#   'SeriesNumber': 12,
#   'Collection': 'Soft-tissue-Sarcoma',
#   'PatientID': 'STS_011',
#   'Manufacturer': 'GE MEDICAL SYSTEMS',
#   'ManufacturerModelName': 'SIGNA EXCITE',
#   'ImageCount': 28,
#   'TimeStamp': '2015-05-27 17:41:13.0',
#   'LicenseName': 'Creative Commons Attribution 3.0 Unported License',
#   'LicenseURI': 'http://creativecommons.org/licenses/by/3.0/',
#   'CollectionURI': 'https://doi.org/10.7937/K9/TCIA.2015.7GO2GSKS',
#   'FileSize': 14743122,
#   'DateReleased': '2015-05-27 17:41:13.0',
#   'StudyDesc': 'MRI RT THIGH',
#   'StudyDate': '2005-09-24 00:00:00.0'},
#  {'SeriesInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.318635353434682000166950888874',
#   'StudyInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.217442582521709510680352762625',
#   'Modality': 'MR',
#   'SeriesDate': '2003-11-18 00:00:00.0',
#   'SeriesDescription': 'AXIAL FSE T1 - RESEARCH',
#   'BodyPartExamined': 'EXTREMITY',
#   'SeriesNumber': 8,
#   'Collection': 'Soft-tissue-Sarcoma',
#   'PatientID': 'STS_014',
#   'Manufacturer': 'GE MEDICAL SYSTEMS',
#   'ManufacturerModelName': 'SIGNA EXCITE',
#   'ImageCount': 54,
#   'TimeStamp': '2015-05-27 17:41:27.0',
#   'LicenseName': 'Creative Commons Attribution 3.0 Unported License',
#   'LicenseURI': 'http://creativecommons.org/licenses/by/3.0/',
#   'CollectionURI': 'https://doi.org/10.7937/K9/TCIA.2015.7GO2GSKS',
#   'FileSize': 28433782,
#   'DateReleased': '2015-05-27 17:41:27.0',
#   'StudyDesc': 'B MRI-RT THIGH',
#   'StudyDate': '2003-11-18 00:00:00.0'},
#  {'SeriesInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.195901281264900039997063449243',
#   'StudyInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.217442582521709510680352762625',
#   'Modality': 'MR',
#   'SeriesDate': '2003-11-18 00:00:00.0',
#   'SeriesDescription': 'AXIAL FRFSE T2 Fatsat - RESEARCH',
#   'BodyPartExamined': 'EXTREMITY',
#   'SeriesNumber': 9,
#   'Collection': 'Soft-tissue-Sarcoma',
#   'PatientID': 'STS_014',
#   'Manufacturer': 'GE MEDICAL SYSTEMS',
#   'ManufacturerModelName': 'SIGNA EXCITE',
#   'ImageCount': 54,
#   'TimeStamp': '2015-05-27 17:41:41.0',
#   'LicenseName': 'Creative Commons Attribution 3.0 Unported License',
#   'LicenseURI': 'http://creativecommons.org/licenses/by/3.0/',
#   'CollectionURI': 'https://doi.org/10.7937/K9/TCIA.2015.7GO2GSKS',
#   'FileSize': 28434210,
#   'DateReleased': '2015-05-27 17:41:41.0',
#   'StudyDesc': 'B MRI-RT THIGH',
#   'StudyDate': '2003-11-18 00:00:00.0'},
#  {'SeriesInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.420647284067341373918324453507',
#   'StudyInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.631882130174760778769870833390',
#   'Modality': 'MR',
#   'SeriesDate': '2004-03-12 00:00:00.0',
#   'SeriesDescription': 'Axial T1 UPPER - RESEARCH',
#   'BodyPartExamined': 'EXTREMITY',
#   'SeriesNumber': 100,
#   'Collection': 'Soft-tissue-Sarcoma',
#   'PatientID': 'STS_009',
#   'Manufacturer': 'GE MEDICAL SYSTEMS',
#   'ManufacturerModelName': 'SIGNA EXCITE',
#   'ImageCount': 65,
#   'TimeStamp': '2015-05-27 17:41:50.0',
#   'LicenseName': 'Creative Commons Attribution 3.0 Unported License',
#   'LicenseURI': 'http://creativecommons.org/licenses/by/3.0/',
#   'CollectionURI': 'https://doi.org/10.7937/K9/TCIA.2015.7GO2GSKS',
#   'FileSize': 34223630,
#   'DateReleased': '2015-05-27 17:41:50.0',
#   'StudyDesc': 'MRI-RT THIGH',
#   'StudyDate': '2004-03-12 00:00:00.0'},
#  {'SeriesInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.808233697012611442522299876380',
#   'StudyInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.631882130174760778769870833390',
#   'Modality': 'MR',
#   'SeriesDate': '2004-03-12 00:00:00.0',
#   'SeriesDescription': 'Axial FSE/T2 FS UPPER',
#   'BodyPartExamined': 'EXTREMITY',
#   'SeriesNumber': 101,
#   'Collection': 'Soft-tissue-Sarcoma',
#   'PatientID': 'STS_009',
#   'Manufacturer': 'GE MEDICAL SYSTEMS',
#   'ManufacturerModelName': 'SIGNA EXCITE',
#   'ImageCount': 65,
#   'TimeStamp': '2015-05-27 17:42:10.0',
#   'LicenseName': 'Creative Commons Attribution 3.0 Unported License',
#   'LicenseURI': 'http://creativecommons.org/licenses/by/3.0/',
#   'CollectionURI': 'https://doi.org/10.7937/K9/TCIA.2015.7GO2GSKS',
#   'FileSize': 34223386,
#   'DateReleased': '2015-05-27 17:42:10.0',
#   'StudyDesc': 'MRI-RT THIGH',
#   'StudyDate': '2004-03-12 00:00:00.0'},
#  {'SeriesInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.275920362343757868508720170893',
#   'StudyInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.192336256049048465660085909602',
#   'Modality': 'MR',
#   'SeriesDate': '2001-01-27 00:00:00.0',
#   'SeriesDescription': 'Axial T1 - RESEARCH',
#   'BodyPartExamined': 'EXTREMITY',
#   'SeriesNumber': 4,
#   'Collection': 'Soft-tissue-Sarcoma',
#   'PatientID': 'STS_043',
#   'Manufacturer': 'GE MEDICAL SYSTEMS',
#   'ManufacturerModelName': 'SIGNA EXCITE',
#   'ImageCount': 30,
#   'TimeStamp': '2015-05-27 17:42:13.0',
#   'LicenseName': 'Creative Commons Attribution 3.0 Unported License',
#   'LicenseURI': 'http://creativecommons.org/licenses/by/3.0/',
#   'CollectionURI': 'https://doi.org/10.7937/K9/TCIA.2015.7GO2GSKS',
#   'FileSize': 15796198,
#   'DateReleased': '2015-05-27 17:42:13.0',
#   'StudyDesc': 'B LT THIGH',
#   'StudyDate': '2001-01-27 00:00:00.0'},
#  {'SeriesInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.833402755673698850614173683036',
#   'StudyInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.192336256049048465660085909602',
#   'Modality': 'MR',
#   'SeriesDate': '2001-01-27 00:00:00.0',
#   'SeriesDescription': 'Axial FSE/T2 Fatsat - RESEARCH',
#   'BodyPartExamined': 'EXTREMITY',
#   'SeriesNumber': 5,
#   'Collection': 'Soft-tissue-Sarcoma',
#   'PatientID': 'STS_043',
#   'Manufacturer': 'GE MEDICAL SYSTEMS',
#   'ManufacturerModelName': 'SIGNA EXCITE',
#   'ImageCount': 33,
#   'TimeStamp': '2015-05-27 17:42:20.0',
#   'LicenseName': 'Creative Commons Attribution 3.0 Unported License',
#   'LicenseURI': 'http://creativecommons.org/licenses/by/3.0/',
#   'CollectionURI': 'https://doi.org/10.7937/K9/TCIA.2015.7GO2GSKS',
#   'FileSize': 17376082,
#   'DateReleased': '2015-05-27 17:42:20.0',
#   'StudyDesc': 'B LT THIGH',
#   'StudyDate': '2001-01-27 00:00:00.0'},
#  {'SeriesInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.100810106392866374474424222764',
#   'StudyInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.144872797786633980009202939938',
#   'Modality': 'MR',
#   'SeriesDate': '2006-03-28 00:00:00.0',
#   'SeriesDescription': 'Axial FSE/T1',
#   'BodyPartExamined': 'EXTREMITY',
#   'SeriesNumber': 6,
#   'Collection': 'Soft-tissue-Sarcoma',
#   'PatientID': 'STS_048',
#   'Manufacturer': 'GE MEDICAL SYSTEMS',
#   'ManufacturerModelName': 'SIGNA EXCITE',
#   'ImageCount': 33,
#   'TimeStamp': '2015-05-27 17:42:27.0',
#   'LicenseName': 'Creative Commons Attribution 3.0 Unported License',
#   'LicenseURI': 'http://creativecommons.org/licenses/by/3.0/',
#   'CollectionURI': 'https://doi.org/10.7937/K9/TCIA.2015.7GO2GSKS',
#   'FileSize': 17374482,
#   'DateReleased': '2015-05-27 17:42:27.0',
#   'StudyDesc': 'B MRI THIGH C+- LEFT',
#   'StudyDate': '2006-03-28 00:00:00.0'},
#  {'SeriesInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.116696671154927334460864159471',
#   'StudyInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.144872797786633980009202939938',
#   'Modality': 'MR',
#   'SeriesDate': '2006-03-28 00:00:00.0',
#   'SeriesDescription': 'Axial FSE/T2 Fatsat',
#   'BodyPartExamined': 'EXTREMITY',
#   'SeriesNumber': 7,
#   'Collection': 'Soft-tissue-Sarcoma',
#   'PatientID': 'STS_048',
#   'Manufacturer': 'GE MEDICAL SYSTEMS',
#   'ManufacturerModelName': 'SIGNA EXCITE',
#   'ImageCount': 33,
#   'TimeStamp': '2015-05-27 17:42:34.0',
#   'LicenseName': 'Creative Commons Attribution 3.0 Unported License',
#   'LicenseURI': 'http://creativecommons.org/licenses/by/3.0/',
#   'CollectionURI': 'https://doi.org/10.7937/K9/TCIA.2015.7GO2GSKS',
#   'FileSize': 17374746,
#   'DateReleased': '2015-05-27 17:42:34.0',
#   'StudyDesc': 'B MRI THIGH C+- LEFT',
#   'StudyDate': '2006-03-28 00:00:00.0'},
#  {'SeriesInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.180149795845416300113932304406',
#   'StudyInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.298197801662493866230089517321',
#   'Modality': 'MR',
#   'SeriesDate': '2006-05-10 00:00:00.0',
#   'SeriesDescription': 'Coronal Fast Stir',
#   'BodyPartExamined': 'EXTREMITY',
#   'SeriesNumber': 4,
#   'Collection': 'Soft-tissue-Sarcoma',
#   'PatientID': 'STS_020',
#   'Manufacturer': 'GE MEDICAL SYSTEMS',
#   'ManufacturerModelName': 'SIGNA EXCITE',
#   'ImageCount': 30,
#   'TimeStamp': '2015-05-27 17:42:41.0',
#   'LicenseName': 'Creative Commons Attribution 3.0 Unported License',
#   'LicenseURI': 'http://creativecommons.org/licenses/by/3.0/',
#   'CollectionURI': 'https://doi.org/10.7937/K9/TCIA.2015.7GO2GSKS',
#   'FileSize': 15795612,
#   'DateReleased': '2015-05-27 17:42:41.0',
#   'StudyDesc': 'B  MRI THIGH C- LEFT',
#   'StudyDate': '2006-05-10 00:00:00.0'},
#  {'SeriesInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.101157489241943635211782299237',
#   'StudyInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.298197801662493866230089517321',
#   'Modality': 'MR',
#   'SeriesDate': '2006-05-10 00:00:00.0',
#   'SeriesDescription': 'Coronal FSE/T1',
#   'BodyPartExamined': 'EXTREMITY',
#   'SeriesNumber': 3,
#   'Collection': 'Soft-tissue-Sarcoma',
#   'PatientID': 'STS_020',
#   'Manufacturer': 'GE MEDICAL SYSTEMS',
#   'ManufacturerModelName': 'SIGNA EXCITE',
#   'ImageCount': 32,
#   'TimeStamp': '2015-05-27 17:42:48.0',
#   'LicenseName': 'Creative Commons Attribution 3.0 Unported License',
#   'LicenseURI': 'http://creativecommons.org/licenses/by/3.0/',
#   'CollectionURI': 'https://doi.org/10.7937/K9/TCIA.2015.7GO2GSKS',
#   'FileSize': 16848366,
#   'DateReleased': '2015-05-27 17:42:48.0',
#   'StudyDesc': 'B  MRI THIGH C- LEFT',
#   'StudyDate': '2006-05-10 00:00:00.0'},
#  {'SeriesInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.191464830789703333705390160452',
#   'StudyInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.196839546704358276848073669873',
#   'Modality': 'MR',
#   'SeriesDate': '2004-01-02 00:00:00.0',
#   'SeriesDescription': 'Axial T1 - RESEARCH',
#   'BodyPartExamined': 'EXTREMITY',
#   'SeriesNumber': 4,
#   'Collection': 'Soft-tissue-Sarcoma',
#   'PatientID': 'STS_028',
#   'Manufacturer': 'GE MEDICAL SYSTEMS',
#   'ManufacturerModelName': 'SIGNA EXCITE',
#   'ImageCount': 38,
#   'TimeStamp': '2015-05-27 17:43:01.0',
#   'LicenseName': 'Creative Commons Attribution 3.0 Unported License',
#   'LicenseURI': 'http://creativecommons.org/licenses/by/3.0/',
#   'CollectionURI': 'https://doi.org/10.7937/K9/TCIA.2015.7GO2GSKS',
#   'FileSize': 20006712,
#   'DateReleased': '2015-05-27 17:43:01.0',
#   'StudyDesc': 'MRI-LT LEG',
#   'StudyDate': '2004-01-02 00:00:00.0'},
#  {'SeriesInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.243455695563553146225724723758',
#   'StudyInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.196839546704358276848073669873',
#   'Modality': 'MR',
#   'SeriesDate': '2004-01-02 00:00:00.0',
#   'SeriesDescription': 'Axial FSE/T2 Fatsat - RESEARCH',
#   'BodyPartExamined': 'EXTREMITY',
#   'SeriesNumber': 5,
#   'Collection': 'Soft-tissue-Sarcoma',
#   'PatientID': 'STS_028',
#   'Manufacturer': 'GE MEDICAL SYSTEMS',
#   'ManufacturerModelName': 'SIGNA EXCITE',
#   'ImageCount': 38,
#   'TimeStamp': '2015-05-27 17:43:09.0',
#   'LicenseName': 'Creative Commons Attribution 3.0 Unported License',
#   'LicenseURI': 'http://creativecommons.org/licenses/by/3.0/',
#   'CollectionURI': 'https://doi.org/10.7937/K9/TCIA.2015.7GO2GSKS',
#   'FileSize': 20007024,
#   'DateReleased': '2015-05-27 17:43:09.0',
#   'StudyDesc': 'MRI-LT LEG',
#   'StudyDate': '2004-01-02 00:00:00.0'},
#  {'SeriesInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.277744416008614854051182995003',
#   'StudyInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.111545328300494498964255686708',
#   'Modality': 'MR',
#   'SeriesDate': '2005-10-08 00:00:00.0',
#   'SeriesDescription': 'Coronal Fast Stir',
#   'BodyPartExamined': 'EXTREMITY',
#   'SeriesNumber': 6,
#   'Collection': 'Soft-tissue-Sarcoma',
#   'PatientID': 'STS_029',
#   'Manufacturer': 'GE MEDICAL SYSTEMS',
#   'ManufacturerModelName': 'SIGNA EXCITE',
#   'ImageCount': 30,
#   'TimeStamp': '2015-05-27 17:43:16.0',
#   'LicenseName': 'Creative Commons Attribution 3.0 Unported License',
#   'LicenseURI': 'http://creativecommons.org/licenses/by/3.0/',
#   'CollectionURI': 'https://doi.org/10.7937/K9/TCIA.2015.7GO2GSKS',
#   'FileSize': 15795430,
#   'DateReleased': '2015-05-27 17:43:16.0',
#   'StudyDesc': 'MRI THIGH C+ LEFT',
#   'StudyDate': '2005-10-08 00:00:00.0'},
#  {'SeriesInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.499068291692658432787865557944',
#   'StudyInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.111545328300494498964255686708',
#   'Modality': 'MR',
#   'SeriesDate': '2005-10-08 00:00:00.0',
#   'SeriesDescription': 'Axial T1  LT THIGH',
#   'BodyPartExamined': 'EXTREMITY',
#   'SeriesNumber': 7,
#   'Collection': 'Soft-tissue-Sarcoma',
#   'PatientID': 'STS_029',
#   'Manufacturer': 'GE MEDICAL SYSTEMS',
#   'ManufacturerModelName': 'SIGNA EXCITE',
#   'ImageCount': 40,
#   'TimeStamp': '2015-05-27 17:43:24.0',
#   'LicenseName': 'Creative Commons Attribution 3.0 Unported License',
#   'LicenseURI': 'http://creativecommons.org/licenses/by/3.0/',
#   'CollectionURI': 'https://doi.org/10.7937/K9/TCIA.2015.7GO2GSKS',
#   'FileSize': 21060368,
#   'DateReleased': '2015-05-27 17:43:24.0',
#   'StudyDesc': 'MRI THIGH C+ LEFT',
#   'StudyDate': '2005-10-08 00:00:00.0'},
#  {'SeriesInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.102205070502998247876240264257',
#   'StudyInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.905975299888796056144178475289',
#   'Modality': 'MR',
#   'SeriesDate': '2004-11-19 00:00:00.0',
#   'SeriesDescription': 'Axial T1 RT HIP/ THIGH',
#   'BodyPartExamined': 'EXTREMITY',
#   'SeriesNumber': 3,
#   'Collection': 'Soft-tissue-Sarcoma',
#   'PatientID': 'STS_031',
#   'Manufacturer': 'GE MEDICAL SYSTEMS',
#   'ManufacturerModelName': 'SIGNA EXCITE',
#   'ImageCount': 36,
#   'TimeStamp': '2015-05-27 17:43:32.0',
#   'LicenseName': 'Creative Commons Attribution 3.0 Unported License',
#   'LicenseURI': 'http://creativecommons.org/licenses/by/3.0/',
#   'CollectionURI': 'https://doi.org/10.7937/K9/TCIA.2015.7GO2GSKS',
#   'FileSize': 18954208,
#   'DateReleased': '2015-05-27 17:43:32.0',
#   'StudyDesc': 'MRI-RT BUTTOCK',
#   'StudyDate': '2004-11-19 00:00:00.0'},
#  {'SeriesInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.319852203736777098394532396060',
#   'StudyInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.905975299888796056144178475289',
#   'Modality': 'MR',
#   'SeriesDate': '2004-11-19 00:00:00.0',
#   'SeriesDescription': 'Axial T2 FS RT HIP/THIGH',
#   'BodyPartExamined': 'EXTREMITY',
#   'SeriesNumber': 4,
#   'Collection': 'Soft-tissue-Sarcoma',
#   'PatientID': 'STS_031',
#   'Manufacturer': 'GE MEDICAL SYSTEMS',
#   'ManufacturerModelName': 'SIGNA EXCITE',
#   'ImageCount': 36,
#   'TimeStamp': '2015-05-27 17:43:39.0',
#   'LicenseName': 'Creative Commons Attribution 3.0 Unported License',
#   'LicenseURI': 'http://creativecommons.org/licenses/by/3.0/',
#   'CollectionURI': 'https://doi.org/10.7937/K9/TCIA.2015.7GO2GSKS',
#   'FileSize': 18954274,
#   'DateReleased': '2015-05-27 17:43:39.0',
#   'StudyDesc': 'MRI-RT BUTTOCK',
#   'StudyDate': '2004-11-19 00:00:00.0'},
#  {'SeriesInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.311541396855223962525824591318',
#   'StudyInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.374101138583106903679226367573',
#   'Modality': 'MR',
#   'SeriesDate': '2004-02-21 00:00:00.0',
#   'SeriesDescription': 'Axial FSE/T1 - RESEARCH',
#   'BodyPartExamined': 'EXTREMITY',
#   'SeriesNumber': 8,
#   'Collection': 'Soft-tissue-Sarcoma',
#   'PatientID': 'STS_033',
#   'Manufacturer': 'GE MEDICAL SYSTEMS',
#   'ManufacturerModelName': 'SIGNA EXCITE',
#   'ImageCount': 42,
#   'TimeStamp': '2015-05-27 17:43:52.0',
#   'LicenseName': 'Creative Commons Attribution 3.0 Unported License',
#   'LicenseURI': 'http://creativecommons.org/licenses/by/3.0/',
#   'CollectionURI': 'https://doi.org/10.7937/K9/TCIA.2015.7GO2GSKS',
#   'FileSize': 22113320,
#   'DateReleased': '2015-05-27 17:43:52.0',
#   'StudyDesc': 'B MRI-LT THIGH',
#   'StudyDate': '2004-02-21 00:00:00.0'},
#  {'SeriesInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.338923641901222312865482201539',
#   'StudyInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.374101138583106903679226367573',
#   'Modality': 'MR',
#   'SeriesDate': '2004-02-21 00:00:00.0',
#   'SeriesDescription': 'Axial FSE/T2 Fatsat - RESEARCH',
#   'BodyPartExamined': 'EXTREMITY',
#   'SeriesNumber': 10,
#   'Collection': 'Soft-tissue-Sarcoma',
#   'PatientID': 'STS_033',
#   'Manufacturer': 'GE MEDICAL SYSTEMS',
#   'ManufacturerModelName': 'SIGNA EXCITE',
#   'ImageCount': 42,
#   'TimeStamp': '2015-05-27 17:44:00.0',
#   'LicenseName': 'Creative Commons Attribution 3.0 Unported License',
#   'LicenseURI': 'http://creativecommons.org/licenses/by/3.0/',
#   'CollectionURI': 'https://doi.org/10.7937/K9/TCIA.2015.7GO2GSKS',
#   'FileSize': 22113566,
#   'DateReleased': '2015-05-27 17:44:00.0',
#   'StudyDesc': 'B MRI-LT THIGH',
#   'StudyDate': '2004-02-21 00:00:00.0'},
#  {'SeriesInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.307548917421553313700518591655',
#   'StudyInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.139892171772667234059236415202',
#   'Modality': 'MR',
#   'SeriesDate': '2002-04-14 00:00:00.0',
#   'SeriesDescription': 'Axial FSE/T1 LOWER TIB FIB - RESEARCH',
#   'BodyPartExamined': 'EXTREMITY',
#   'SeriesNumber': 12,
#   'Collection': 'Soft-tissue-Sarcoma',
#   'PatientID': 'STS_049',
#   'Manufacturer': 'GE MEDICAL SYSTEMS',
#   'ManufacturerModelName': 'SIGNA EXCITE',
#   'ImageCount': 34,
#   'TimeStamp': '2015-05-27 17:44:08.0',
#   'LicenseName': 'Creative Commons Attribution 3.0 Unported License',
#   'LicenseURI': 'http://creativecommons.org/licenses/by/3.0/',
#   'CollectionURI': 'https://doi.org/10.7937/K9/TCIA.2015.7GO2GSKS',
#   'FileSize': 17903248,
#   'DateReleased': '2015-05-27 17:44:08.0',
#   'StudyDesc': 'MRI-UNLISTED AREA',
#   'StudyDate': '2002-04-14 00:00:00.0'},
#  {'SeriesInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.106714122321760501335072230537',
#   'StudyInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.139892171772667234059236415202',
#   'Modality': 'MR',
#   'SeriesDate': '2002-04-14 00:00:00.0',
#   'SeriesDescription': 'Axial FSE/T2 Fatsat LOWER TIB FIB - RESEARCH',
#   'BodyPartExamined': 'EXTREMITY',
#   'SeriesNumber': 9,
#   'Collection': 'Soft-tissue-Sarcoma',
#   'PatientID': 'STS_049',
#   'Manufacturer': 'GE MEDICAL SYSTEMS',
#   'ManufacturerModelName': 'SIGNA EXCITE',
#   'ImageCount': 39,
#   'TimeStamp': '2015-05-27 17:44:15.0',
#   'LicenseName': 'Creative Commons Attribution 3.0 Unported License',
#   'LicenseURI': 'http://creativecommons.org/licenses/by/3.0/',
#   'CollectionURI': 'https://doi.org/10.7937/K9/TCIA.2015.7GO2GSKS',
#   'FileSize': 20536350,
#   'DateReleased': '2015-05-27 17:44:15.0',
#   'StudyDesc': 'MRI-UNLISTED AREA',
#   'StudyDate': '2002-04-14 00:00:00.0'},
#  {'SeriesInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.566651395428914683664036880461',
#   'StudyInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.381934155831118942112891377892',
#   'Modality': 'MR',
#   'SeriesDate': '2004-01-02 00:00:00.0',
#   'SeriesDescription': 'AX STIR',
#   'BodyPartExamined': 'EXTREMITY',
#   'SeriesNumber': 7,
#   'Collection': 'Soft-tissue-Sarcoma',
#   'PatientID': 'STS_050',
#   'Manufacturer': 'GE MEDICAL SYSTEMS',
#   'ManufacturerModelName': 'SIGNA EXCITE',
#   'ImageCount': 30,
#   'TimeStamp': '2015-05-27 17:44:22.0',
#   'LicenseName': 'Creative Commons Attribution 3.0 Unported License',
#   'LicenseURI': 'http://creativecommons.org/licenses/by/3.0/',
#   'CollectionURI': 'https://doi.org/10.7937/K9/TCIA.2015.7GO2GSKS',
#   'FileSize': 15795154,
#   'DateReleased': '2015-05-27 17:44:22.0',
#   'StudyDesc': 'IRM FEMUR GAUCHE C-/C+',
#   'StudyDate': '2004-01-02 00:00:00.0'},
#  {'SeriesInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.964355166778723647238430080651',
#   'StudyInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.381934155831118942112891377892',
#   'Modality': 'MR',
#   'SeriesDate': '2004-01-02 00:00:00.0',
#   'SeriesDescription': 'AXI T1 FSE - RESEARCH',
#   'BodyPartExamined': 'EXTREMITY',
#   'SeriesNumber': 6,
#   'Collection': 'Soft-tissue-Sarcoma',
#   'PatientID': 'STS_050',
#   'Manufacturer': 'GE MEDICAL SYSTEMS',
#   'ManufacturerModelName': 'SIGNA EXCITE',
#   'ImageCount': 30,
#   'TimeStamp': '2015-05-27 17:44:31.0',
#   'LicenseName': 'Creative Commons Attribution 3.0 Unported License',
#   'LicenseURI': 'http://creativecommons.org/licenses/by/3.0/',
#   'CollectionURI': 'https://doi.org/10.7937/K9/TCIA.2015.7GO2GSKS',
#   'FileSize': 15795654,
#   'DateReleased': '2015-05-27 17:44:31.0',
#   'StudyDesc': 'IRM FEMUR GAUCHE C-/C+',
#   'StudyDate': '2004-01-02 00:00:00.0'},
#  {'SeriesInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.248651241073318412327493263601',
#   'StudyInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.157038102368099146894464583211',
#   'Modality': 'MR',
#   'SeriesDate': '2004-06-02 00:00:00.0',
#   'SeriesDescription': 'AXIAL FSE T1 PELVIS',
#   'BodyPartExamined': 'EXTREMITY',
#   'SeriesNumber': 5,
#   'Collection': 'Soft-tissue-Sarcoma',
#   'PatientID': 'STS_018',
#   'Manufacturer': 'GE MEDICAL SYSTEMS',
#   'ManufacturerModelName': 'SIGNA EXCITE',
#   'ImageCount': 42,
#   'TimeStamp': '2015-05-27 17:44:44.0',
#   'LicenseName': 'Creative Commons Attribution 3.0 Unported License',
#   'LicenseURI': 'http://creativecommons.org/licenses/by/3.0/',
#   'CollectionURI': 'https://doi.org/10.7937/K9/TCIA.2015.7GO2GSKS',
#   'FileSize': 22112964,
#   'DateReleased': '2015-05-27 17:44:44.0',
#   'StudyDesc': 'MRI-PELVIS',
#   'StudyDate': '2004-06-02 00:00:00.0'},
#  {'SeriesInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.275797706830644847544165749184',
#   'StudyInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.157038102368099146894464583211',
#   'Modality': 'MR',
#   'SeriesDate': '2004-06-02 00:00:00.0',
#   'SeriesDescription': 'AXIAL FRFSE T2 Fatsat Pelvis',
#   'BodyPartExamined': 'EXTREMITY',
#   'SeriesNumber': 6,
#   'Collection': 'Soft-tissue-Sarcoma',
#   'PatientID': 'STS_018',
#   'Manufacturer': 'GE MEDICAL SYSTEMS',
#   'ManufacturerModelName': 'SIGNA EXCITE',
#   'ImageCount': 42,
#   'TimeStamp': '2015-05-27 17:44:52.0',
#   'LicenseName': 'Creative Commons Attribution 3.0 Unported License',
#   'LicenseURI': 'http://creativecommons.org/licenses/by/3.0/',
#   'CollectionURI': 'https://doi.org/10.7937/K9/TCIA.2015.7GO2GSKS',
#   'FileSize': 22113402,
#   'DateReleased': '2015-05-27 17:44:52.0',
#   'StudyDesc': 'MRI-PELVIS',
#   'StudyDate': '2004-06-02 00:00:00.0'},
#  {'SeriesInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.808562447467517056151435813598',
#   'StudyInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.296297765945483063120242483189',
#   'Modality': 'MR',
#   'SeriesDate': '2002-05-01 00:00:00.0',
#   'SeriesDescription': 'Coronal Fast Stir - RESEARCH',
#   'BodyPartExamined': 'EXTREMITY',
#   'SeriesNumber': 3,
#   'Collection': 'Soft-tissue-Sarcoma',
#   'PatientID': 'STS_027',
#   'Manufacturer': 'GE MEDICAL SYSTEMS',
#   'ManufacturerModelName': 'SIGNA EXCITE',
#   'ImageCount': 32,
#   'TimeStamp': '2015-05-27 17:44:59.0',
#   'LicenseName': 'Creative Commons Attribution 3.0 Unported License',
#   'LicenseURI': 'http://creativecommons.org/licenses/by/3.0/',
#   'CollectionURI': 'https://doi.org/10.7937/K9/TCIA.2015.7GO2GSKS',
#   'FileSize': 16848454,
#   'DateReleased': '2015-05-27 17:44:59.0',
#   'StudyDesc': 'B LT THIGH',
#   'StudyDate': '2002-05-01 00:00:00.0'},
#  {'SeriesInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.244839656266930244980615831729',
#   'StudyInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.296297765945483063120242483189',
#   'Modality': 'MR',
#   'SeriesDate': '2002-05-01 00:00:00.0',
#   'SeriesDescription': 'Coronal FSE/T1 - RESEARCH',
#   'BodyPartExamined': 'EXTREMITY',
#   'SeriesNumber': 2,
#   'Collection': 'Soft-tissue-Sarcoma',
#   'PatientID': 'STS_027',
#   'Manufacturer': 'GE MEDICAL SYSTEMS',
#   'ManufacturerModelName': 'SIGNA EXCITE',
#   'ImageCount': 32,
#   'TimeStamp': '2015-05-27 17:45:06.0',
#   'LicenseName': 'Creative Commons Attribution 3.0 Unported License',
#   'LicenseURI': 'http://creativecommons.org/licenses/by/3.0/',
#   'CollectionURI': 'https://doi.org/10.7937/K9/TCIA.2015.7GO2GSKS',
#   'FileSize': 16848134,
#   'DateReleased': '2015-05-27 17:45:06.0',
#   'StudyDesc': 'B LT THIGH',
#   'StudyDate': '2002-05-01 00:00:00.0'},
#  {'SeriesInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.239403345440430042936684336653',
#   'StudyInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.285149579964815316342763835661',
#   'Modality': 'MR',
#   'SeriesDate': '2006-04-13 00:00:00.0',
#   'SeriesDescription': 'Axial T1',
#   'BodyPartExamined': 'EXTREMITY',
#   'SeriesNumber': 7,
#   'Collection': 'Soft-tissue-Sarcoma',
#   'PatientID': 'STS_041',
#   'Manufacturer': 'GE MEDICAL SYSTEMS',
#   'ManufacturerModelName': 'SIGNA EXCITE',
#   'ImageCount': 42,
#   'TimeStamp': '2015-05-27 17:45:19.0',
#   'LicenseName': 'Creative Commons Attribution 3.0 Unported License',
#   'LicenseURI': 'http://creativecommons.org/licenses/by/3.0/',
#   'CollectionURI': 'https://doi.org/10.7937/K9/TCIA.2015.7GO2GSKS',
#   'FileSize': 22114034,
#   'DateReleased': '2015-05-27 17:45:19.0',
#   'StudyDesc': 'MRI THIGH C+ RIGHT',
#   'StudyDate': '2006-04-13 00:00:00.0'},
#  {'SeriesInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.268647359786145413268994310237',
#   'StudyInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.285149579964815316342763835661',
#   'Modality': 'MR',
#   'SeriesDate': '2006-04-13 00:00:00.0',
#   'SeriesDescription': 'Axial FSE/T2 Fatsat',
#   'BodyPartExamined': 'EXTREMITY',
#   'SeriesNumber': 8,
#   'Collection': 'Soft-tissue-Sarcoma',
#   'PatientID': 'STS_041',
#   'Manufacturer': 'GE MEDICAL SYSTEMS',
#   'ManufacturerModelName': 'SIGNA EXCITE',
#   'ImageCount': 42,
#   'TimeStamp': '2015-05-27 17:45:27.0',
#   'LicenseName': 'Creative Commons Attribution 3.0 Unported License',
#   'LicenseURI': 'http://creativecommons.org/licenses/by/3.0/',
#   'CollectionURI': 'https://doi.org/10.7937/K9/TCIA.2015.7GO2GSKS',
#   'FileSize': 22114538,
#   'DateReleased': '2015-05-27 17:45:27.0',
#   'StudyDesc': 'MRI THIGH C+ RIGHT',
#   'StudyDate': '2006-04-13 00:00:00.0'},
#  {'SeriesInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.806679014603095689025255756775',
#   'StudyInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.311778395054988860158230766014',
#   'Modality': 'MR',
#   'SeriesDate': '2004-05-29 00:00:00.0',
#   'SeriesDescription': 'Axial T1 - RESEARCH',
#   'BodyPartExamined': 'EXTREMITY',
#   'SeriesNumber': 4,
#   'Collection': 'Soft-tissue-Sarcoma',
#   'PatientID': 'STS_007',
#   'Manufacturer': 'GE MEDICAL SYSTEMS',
#   'ManufacturerModelName': 'SIGNA EXCITE',
#   'ImageCount': 54,
#   'TimeStamp': '2015-05-27 17:45:41.0',
#   'LicenseName': 'Creative Commons Attribution 3.0 Unported License',
# ...
#   'TimeStamp': '2015-05-27 18:02:08.0',
#   'LicenseName': 'Creative Commons Attribution 3.0 Unported License',
#   'LicenseURI': 'http://creativecommons.org/licenses/by/3.0/',
#   'CollectionURI': 'https://doi.org/10.7937/K9/TCIA.2015.7GO2GSKS',
#   'FileSize': 11889260,
#   'DateReleased': '2015-05-27 18:02:08.0',
#   'StudyDesc': 'IRM - CUISSE GAUCHE',
#   'StudyDate': '2005-12-15 00:00:00.0'},
#  {'SeriesInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.192494973570981860314241293571',
#   'StudyInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.124523531702432924263844540542',
#   'Modality': 'MR',
#   'SeriesDate': '2000-08-24 00:00:00.0',
#   'SeriesDescription': 'Aligned_STIRtoPET_BOX',
#   'BodyPartExamined': 'EXTREMITY',
#   'SeriesNumber': 7470024,
#   'Collection': 'Soft-tissue-Sarcoma',
#   'PatientID': 'STS_025',
#   'Manufacturer': 'SIEMENS / MIM Software',
#   'ManufacturerModelName': 'Sonata',
#   'ImageCount': 28,
#   'TimeStamp': '2015-05-27 18:02:23.0',
#   'LicenseName': 'Creative Commons Attribution 3.0 Unported License',
#   'LicenseURI': 'http://creativecommons.org/licenses/by/3.0/',
#   'CollectionURI': 'https://doi.org/10.7937/K9/TCIA.2015.7GO2GSKS',
#   'FileSize': 321460,
#   'DateReleased': '2015-05-27 18:02:23.0',
#   'StudyDesc': 'PET CT with registered MR',
#   'StudyDate': '2000-10-04 00:00:00.0'},
#  {'SeriesInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.223315283357097349129348266041',
#   'StudyInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.124523531702432924263844540542',
#   'Modality': 'MR',
#   'SeriesDate': '2000-08-24 00:00:00.0',
#   'SeriesDescription': 'Aligned_T1toPET_BOX',
#   'BodyPartExamined': 'EXTREMITY',
#   'SeriesNumber': 746402,
#   'Collection': 'Soft-tissue-Sarcoma',
#   'PatientID': 'STS_025',
#   'Manufacturer': 'SIEMENS / MIM Software',
#   'ManufacturerModelName': 'Sonata',
#   'ImageCount': 25,
#   'TimeStamp': '2015-05-27 18:02:29.0',
#   'LicenseName': 'Creative Commons Attribution 3.0 Unported License',
#   'LicenseURI': 'http://creativecommons.org/licenses/by/3.0/',
#   'CollectionURI': 'https://doi.org/10.7937/K9/TCIA.2015.7GO2GSKS',
#   'FileSize': 264264,
#   'DateReleased': '2015-05-27 18:02:29.0',
#   'StudyDesc': 'PET CT with registered MR',
#   'StudyDate': '2000-10-04 00:00:00.0'},
#  {'SeriesInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.156976219335668359365868151301',
#   'StudyInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.253050254328542571464836598460',
#   'Modality': 'MR',
#   'SeriesDate': '1999-06-17 00:00:00.0',
#   'SeriesDescription': 'Aligned_STIRtoPET_BOX',
#   'BodyPartExamined': 'EXTREMITY',
#   'SeriesNumber': 6084033,
#   'Collection': 'Soft-tissue-Sarcoma',
#   'PatientID': 'STS_026',
#   'Manufacturer': 'Philips Medical Systems / MIM Software',
#   'ManufacturerModelName': 'Gyroscan Intera',
#   'ImageCount': 43,
#   'TimeStamp': '2020-05-21 15:29:38.0',
#   'LicenseName': 'Creative Commons Attribution 3.0 Unported License',
#   'LicenseURI': 'http://creativecommons.org/licenses/by/3.0/',
#   'CollectionURI': 'https://doi.org/10.7937/K9/TCIA.2015.7GO2GSKS',
#   'FileSize': 1417910,
#   'DateReleased': '2020-05-21 15:29:38.0',
#   'StudyDesc': 'PET CT with registered MR',
#   'StudyDate': '1999-07-01 00:00:00.0'},
#  {'SeriesInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.685834324045302568921445315927',
#   'StudyInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.253050254328542571464836598460',
#   'Modality': 'MR',
#   'SeriesDate': '2006-02-10 00:00:00.0',
#   'SeriesDescription': 'Aligned_T1toPET_BOX',
#   'BodyPartExamined': 'EXTREMITY',
#   'SeriesNumber': 6078011,
#   'Collection': 'Soft-tissue-Sarcoma',
#   'PatientID': 'STS_026',
#   'Manufacturer': 'Varian Medical Systems / MIM Software',
#   'ManufacturerModelName': 'ARIA RadOnc',
#   'ImageCount': 43,
#   'TimeStamp': '2020-05-21 15:29:39.0',
#   'LicenseName': 'Creative Commons Attribution 3.0 Unported License',
#   'LicenseURI': 'http://creativecommons.org/licenses/by/3.0/',
#   'CollectionURI': 'https://doi.org/10.7937/K9/TCIA.2015.7GO2GSKS',
#   'FileSize': 1494020,
#   'DateReleased': '2020-05-21 15:29:39.0',
#   'StudyDesc': 'PET CT with registered MR',
#   'StudyDate': '1999-07-01 00:00:00.0'},
#  {'SeriesInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.456586726727216425482943792985',
#   'StudyInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.100965969333499185796670639731',
#   'Modality': 'MR',
#   'SeriesDate': '2006-05-18 00:00:00.0',
#   'SeriesDescription': 'Aligned_T1toPET_BOX',
#   'BodyPartExamined': 'EXTREMITY',
#   'SeriesNumber': 4518048,
#   'Collection': 'Soft-tissue-Sarcoma',
#   'PatientID': 'STS_030',
#   'Manufacturer': 'Varian Medical Systems / MIM Software',
#   'ManufacturerModelName': 'ARIA RadOnc',
#   'ImageCount': 121,
#   'TimeStamp': '2015-05-27 18:03:17.0',
#   'LicenseName': 'Creative Commons Attribution 3.0 Unported License',
#   'LicenseURI': 'http://creativecommons.org/licenses/by/3.0/',
#   'CollectionURI': 'https://doi.org/10.7937/K9/TCIA.2015.7GO2GSKS',
#   'FileSize': 14413744,
#   'DateReleased': '2015-05-27 18:03:17.0',
#   'StudyDesc': 'PET CT with registered MR',
#   'StudyDate': '2003-08-28 00:00:00.0'},
#  {'SeriesInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.120738414954862087960495320009',
#   'StudyInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.100965969333499185796670639731',
#   'Modality': 'MR',
#   'SeriesDate': '2006-05-17 00:00:00.0',
#   'SeriesDescription': 'Aligned_T2FStoPET_BOX',
#   'BodyPartExamined': 'EXTREMITY',
#   'SeriesNumber': 4524036,
#   'Collection': 'Soft-tissue-Sarcoma',
#   'PatientID': 'STS_030',
#   'Manufacturer': 'Varian Medical Systems / MIM Software',
#   'ManufacturerModelName': 'ARIA RadOnc',
#   'ImageCount': 118,
#   'TimeStamp': '2015-05-27 18:03:39.0',
#   'LicenseName': 'Creative Commons Attribution 3.0 Unported License',
#   'LicenseURI': 'http://creativecommons.org/licenses/by/3.0/',
#   'CollectionURI': 'https://doi.org/10.7937/K9/TCIA.2015.7GO2GSKS',
#   'FileSize': 13924218,
#   'DateReleased': '2015-05-27 18:03:39.0',
#   'StudyDesc': 'PET CT with registered MR',
#   'StudyDate': '2003-08-28 00:00:00.0'},
#  {'SeriesInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.143218452784035162626040862533',
#   'StudyInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.333438221059842546886114696360',
#   'Modality': 'MR',
#   'SeriesDate': '1999-06-17 00:00:00.0',
#   'SeriesDescription': 'T2ST LT - RESEARCH',
#   'BodyPartExamined': 'EXTREMITY',
#   'SeriesNumber': 501,
#   'Collection': 'Soft-tissue-Sarcoma',
#   'PatientID': 'STS_026',
#   'Manufacturer': 'Philips Medical Systems',
#   'ManufacturerModelName': 'Gyroscan Intera',
#   'ImageCount': 30,
#   'TimeStamp': '2020-05-21 15:29:54.0',
#   'LicenseName': 'Creative Commons Attribution 3.0 Unported License',
#   'LicenseURI': 'http://creativecommons.org/licenses/by/3.0/',
#   'CollectionURI': 'https://doi.org/10.7937/K9/TCIA.2015.7GO2GSKS',
#   'FileSize': 3997500,
#   'DateReleased': '2020-05-21 15:29:54.0',
#   'StudyDesc': 'LEFT THIGH C+',
#   'StudyDate': '1999-06-17 00:00:00.0'},
#  {'SeriesInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.875286913935235283318895687673',
#   'StudyInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.196863983290572645708103783563',
#   'Modality': 'MR',
#   'SeriesDate': '2003-02-05 00:00:00.0',
#   'SeriesDescription': 'Aligned_STIRtoPET_BOX',
#   'BodyPartExamined': 'EXTREMITY',
#   'SeriesNumber': 6570022,
#   'Collection': 'Soft-tissue-Sarcoma',
#   'PatientID': 'STS_035',
#   'Manufacturer': 'SIEMENS / MIM Software',
#   'ManufacturerModelName': 'Espree',
#   'ImageCount': 60,
#   'TimeStamp': '2015-05-27 18:04:33.0',
#   'LicenseName': 'Creative Commons Attribution 3.0 Unported License',
#   'LicenseURI': 'http://creativecommons.org/licenses/by/3.0/',
#   'CollectionURI': 'https://doi.org/10.7937/K9/TCIA.2015.7GO2GSKS',
#   'FileSize': 1144188,
#   'DateReleased': '2015-05-27 18:04:33.0',
#   'StudyDesc': 'PET CT with registered MR',
#   'StudyDate': '2003-04-09 00:00:00.0'},
#  {'SeriesInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.205027620332833569212441189259',
#   'StudyInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.196863983290572645708103783563',
#   'Modality': 'MR',
#   'SeriesDate': '2003-02-05 00:00:00.0',
#   'SeriesDescription': 'Aligned_T1toPET_BOX',
#   'BodyPartExamined': 'EXTREMITY',
#   'SeriesNumber': 6564029,
#   'Collection': 'Soft-tissue-Sarcoma',
#   'PatientID': 'STS_035',
#   'Manufacturer': 'SIEMENS / MIM Software',
#   'ManufacturerModelName': 'Espree',
#   'ImageCount': 54,
#   'TimeStamp': '2015-05-27 18:04:40.0',
#   'LicenseName': 'Creative Commons Attribution 3.0 Unported License',
#   'LicenseURI': 'http://creativecommons.org/licenses/by/3.0/',
#   'CollectionURI': 'https://doi.org/10.7937/K9/TCIA.2015.7GO2GSKS',
#   'FileSize': 1120112,
#   'DateReleased': '2015-05-27 18:04:40.0',
#   'StudyDesc': 'PET CT with registered MR',
#   'StudyDate': '2003-04-09 00:00:00.0'},
#  {'SeriesInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.138972375797863562029440199147',
#   'StudyInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.109604548854137743153429633943',
#   'Modality': 'MR',
#   'SeriesDate': '2004-10-14 00:00:00.0',
#   'SeriesDescription': 'Aligned_STIRtoPET_BOX',
#   'BodyPartExamined': 'EXTREMITY',
#   'SeriesNumber': 7968033,
#   'Collection': 'Soft-tissue-Sarcoma',
#   'PatientID': 'STS_037',
#   'Manufacturer': 'SIEMENS / MIM Software',
#   'ManufacturerModelName': 'Symphony',
#   'ImageCount': 74,
#   'TimeStamp': '2020-05-21 15:30:11.0',
#   'LicenseName': 'Creative Commons Attribution 3.0 Unported License',
#   'LicenseURI': 'http://creativecommons.org/licenses/by/3.0/',
#   'CollectionURI': 'https://doi.org/10.7937/K9/TCIA.2015.7GO2GSKS',
#   'FileSize': 4843144,
#   'DateReleased': '2020-05-21 15:30:11.0',
#   'StudyDesc': 'PET CT with registered MR',
#   'StudyDate': '2004-10-27 00:00:00.0'},
#  {'SeriesInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.155314494644354348297125695292',
#   'StudyInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.109604548854137743153429633943',
#   'Modality': 'MR',
#   'SeriesDate': '2004-10-14 00:00:00.0',
#   'SeriesDescription': 'Aligned_T1toPET_BOX',
#   'BodyPartExamined': 'EXTREMITY',
#   'SeriesNumber': 7956046,
#   'Collection': 'Soft-tissue-Sarcoma',
#   'PatientID': 'STS_037',
#   'Manufacturer': 'SIEMENS / MIM Software',
#   'ManufacturerModelName': 'Symphony',
#   'ImageCount': 81,
#   'TimeStamp': '2020-05-21 15:30:15.0',
#   'LicenseName': 'Creative Commons Attribution 3.0 Unported License',
#   'LicenseURI': 'http://creativecommons.org/licenses/by/3.0/',
#   'CollectionURI': 'https://doi.org/10.7937/K9/TCIA.2015.7GO2GSKS',
#   'FileSize': 6412928,
#   'DateReleased': '2020-05-21 15:30:15.0',
#   'StudyDesc': 'PET CT with registered MR',
#   'StudyDate': '2004-10-27 00:00:00.0'},
#  {'SeriesInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.367947654006930941261451338075',
#   'StudyInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.116609719454223726735489642553',
#   'Modality': 'RTSTRUCT',
#   'SeriesDate': '2000-10-18 00:00:00.0',
#   'SeriesDescription': 'RTStruct_CT',
#   'BodyPartExamined': 'EXTREMITY',
#   'SeriesNumber': 1,
#   'Collection': 'Soft-tissue-Sarcoma',
#   'PatientID': 'STS_046',
#   'Manufacturer': 'MIM Software Inc.',
#   'ManufacturerModelName': 'MIM',
#   'SoftwareVersions': '5.2.3',
#   'ImageCount': 1,
#   'TimeStamp': '2015-06-02 10:50:04.0',
#   'LicenseName': 'Creative Commons Attribution 3.0 Unported License',
#   'LicenseURI': 'http://creativecommons.org/licenses/by/3.0/',
#   'CollectionURI': 'https://doi.org/10.7937/K9/TCIA.2015.7GO2GSKS',
#   'FileSize': 839824,
#   'DateReleased': '2015-06-02 10:50:04.0',
#   'StudyDesc': 'PET CT with registered MR',
#   'StudyDate': '2000-10-18 00:00:00.0'},
#  {'SeriesInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.127816079181949669022628020970',
#   'StudyInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.116609719454223726735489642553',
#   'Modality': 'RTSTRUCT',
#   'SeriesDate': '2008-07-31 00:00:00.0',
#   'SeriesDescription': 'RTStruct_PET',
#   'BodyPartExamined': 'EXTREMITY',
#   'SeriesNumber': 1,
#   'Collection': 'Soft-tissue-Sarcoma',
#   'PatientID': 'STS_046',
#   'Manufacturer': 'MIM Software Inc.',
#   'ManufacturerModelName': 'MIM',
#   'SoftwareVersions': '6.0.2',
#   'ImageCount': 1,
#   'TimeStamp': '2015-06-02 10:50:04.0',
#   'LicenseName': 'Creative Commons Attribution 3.0 Unported License',
#   'LicenseURI': 'http://creativecommons.org/licenses/by/3.0/',
#   'CollectionURI': 'https://doi.org/10.7937/K9/TCIA.2015.7GO2GSKS',
#   'FileSize': 5636660,
#   'DateReleased': '2015-06-02 10:50:04.0',
#   'StudyDesc': 'PET CT with registered MR',
#   'StudyDate': '2000-10-18 00:00:00.0'},
#  {'SeriesInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.151488413517113797900413951742',
#   'StudyInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.320953282443832315370559826627',
#   'Modality': 'MR',
#   'SeriesDate': '1999-03-25 00:00:00.0',
#   'SeriesDescription': 'Aligned_T1toPET_BOX',
#   'BodyPartExamined': 'EXTREMITY',
#   'SeriesNumber': 5916052,
#   'Collection': 'Soft-tissue-Sarcoma',
#   'PatientID': 'STS_047',
#   'Manufacturer': 'Philips Medical Systems / MIM Software',
#   'ManufacturerModelName': 'Gyroscan NT Intera',
#   'ImageCount': 45,
#   'TimeStamp': '2015-05-27 18:05:30.0',
#   'LicenseName': 'Creative Commons Attribution 3.0 Unported License',
#   'LicenseURI': 'http://creativecommons.org/licenses/by/3.0/',
#   'CollectionURI': 'https://doi.org/10.7937/K9/TCIA.2015.7GO2GSKS',
#   'FileSize': 1234914,
#   'DateReleased': '2015-05-27 18:05:30.0',
#   'StudyDesc': 'PET CT with registered MR',
#   'StudyDate': '1999-04-15 00:00:00.0'},
#  {'SeriesInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.188676380466070621196641696309',
#   'StudyInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.320953282443832315370559826627',
#   'Modality': 'MR',
#   'SeriesDate': '1999-03-25 00:00:00.0',
#   'SeriesDescription': 'Aligned_T2FStoPET_BOX',
#   'BodyPartExamined': 'EXTREMITY',
#   'SeriesNumber': 5910040,
#   'Collection': 'Soft-tissue-Sarcoma',
#   'PatientID': 'STS_047',
#   'Manufacturer': 'Philips Medical Systems / MIM Software',
#   'ManufacturerModelName': 'Gyroscan NT Intera',
#   'ImageCount': 44,
#   'TimeStamp': '2015-05-27 18:05:37.0',
#   'LicenseName': 'Creative Commons Attribution 3.0 Unported License',
#   'LicenseURI': 'http://creativecommons.org/licenses/by/3.0/',
#   'CollectionURI': 'https://doi.org/10.7937/K9/TCIA.2015.7GO2GSKS',
#   'FileSize': 1136984,
#   'DateReleased': '2015-05-27 18:05:37.0',
#   'StudyDesc': 'PET CT with registered MR',
#   'StudyDate': '1999-04-15 00:00:00.0'},
#  {'SeriesInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.156381650092010537336149678835',
#   'StudyInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.207362569530299168098522293756',
#   'Modality': 'MR',
#   'SeriesDate': '1999-03-25 00:00:00.0',
#   'SeriesDescription': 'KNEE       *AXT2SP',
#   'BodyPartExamined': 'EXTREMITY',
#   'SeriesNumber': 501,
#   'Collection': 'Soft-tissue-Sarcoma',
#   'PatientID': 'STS_047',
#   'Manufacturer': 'Philips Medical Systems',
#   'ManufacturerModelName': 'Gyroscan NT Intera',
#   'ImageCount': 25,
#   'TimeStamp': '2015-05-27 18:05:44.0',
#   'LicenseName': 'Creative Commons Attribution 3.0 Unported License',
#   'LicenseURI': 'http://creativecommons.org/licenses/by/3.0/',
#   'CollectionURI': 'https://doi.org/10.7937/K9/TCIA.2015.7GO2GSKS',
#   'FileSize': 3331170,
#   'DateReleased': '2015-05-27 18:05:44.0',
#   'StudyDesc': 'B KNEE RT',
#   'StudyDate': '1999-03-25 00:00:00.0'},
#  {'SeriesInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.148008687400367873565766598771',
#   'StudyInstanceUID': '1.3.6.1.4.1.14519.5.2.1.5168.1900.207362569530299168098522293756',
#   'Modality': 'MR',
#   'SeriesDate': '1999-03-25 00:00:00.0',
#   'SeriesDescription': 'KNEE       AX T1',
#   'BodyPartExamined': 'EXTREMITY',
#   'SeriesNumber': 601,
#   'Collection': 'Soft-tissue-Sarcoma',
#   'PatientID': 'STS_047',
#   'Manufacturer': 'Philips Medical Systems',
#   'ManufacturerModelName': 'Gyroscan NT Intera',
#   'ImageCount': 25,
#   'TimeStamp': '2015-05-27 18:05:45.0',
#   'LicenseName': 'Creative Commons Attribution 3.0 Unported License',
#   'LicenseURI': 'http://creativecommons.org/licenses/by/3.0/',
#   'CollectionURI': 'https://doi.org/10.7937/K9/TCIA.2015.7GO2GSKS',
#   'FileSize': 3331120,
#   'DateReleased': '2015-05-27 18:05:45.0',
#   'StudyDesc': 'B KNEE RT',
#   'StudyDate': '1999-03-25 00:00:00.0'}]

# %%
nbia.downloadSeries(data, number = 10)
# Out:
# WARNING:tcia_utils.nbia:Series 1.3.6.1.4.1.14519.5.2.1.5168.1900.104193299251798317056218297018 already downloaded and unzipped.

# %%
import pydicom
import os
import shutil

def organize_dicom_by_patient(base_dir, output_dir):
    # Create output directory if it doesn't exist
    os.makedirs(output_dir, exist_ok=True)

    # Iterate through all the SeriesInstanceUID folders
    for series_folder in os.listdir(base_dir):
        series_path = os.path.join(base_dir, series_folder)

        if os.path.isdir(series_path):
            # Get all DICOM files in the folder
            dicom_files = [f for f in os.listdir(series_path) if f.endswith(".dcm")]

            for dicom_file in dicom_files:
                dicom_path = os.path.join(series_path, dicom_file)
                dicom_data = pydicom.dcmread(dicom_path)

                # Extract Patient ID and Series Description from DICOM file
                patient_id = dicom_data.PatientID
                series_desc = dicom_data.SeriesDescription

                # Create output folder based on Patient ID
                patient_folder = os.path.join(output_dir, f"patient_{patient_id}")
                os.makedirs(patient_folder, exist_ok=True)

                # Copy or move the DICOM file to the patient's folder
                shutil.copy(dicom_path, os.path.join(patient_folder, dicom_file))
                print(f"Copied {dicom_file} to {patient_folder}")

# Set base_dir to where your downloaded DICOM series are
base_dir = "/content/tciaDownload"  # The folder containing SeriesInstanceUID subfolders
output_dir = "./organized_data"

organize_dicom_by_patient(base_dir, output_dir)
# Out:
# Copied 1-44.dcm to ./organized_data/patient_STS_045
# Copied 1-19.dcm to ./organized_data/patient_STS_045
# Copied 1-29.dcm to ./organized_data/patient_STS_045
# Copied 1-42.dcm to ./organized_data/patient_STS_045
# Copied 1-20.dcm to ./organized_data/patient_STS_045
# Copied 1-33.dcm to ./organized_data/patient_STS_045
# Copied 1-16.dcm to ./organized_data/patient_STS_045
# Copied 1-22.dcm to ./organized_data/patient_STS_045
# Copied 1-06.dcm to ./organized_data/patient_STS_045
# Copied 1-14.dcm to ./organized_data/patient_STS_045
# Copied 1-03.dcm to ./organized_data/patient_STS_045
# Copied 1-10.dcm to ./organized_data/patient_STS_045
# Copied 1-43.dcm to ./organized_data/patient_STS_045
# Copied 1-15.dcm to ./organized_data/patient_STS_045
# Copied 1-02.dcm to ./organized_data/patient_STS_045
# Copied 1-04.dcm to ./organized_data/patient_STS_045
# Copied 1-08.dcm to ./organized_data/patient_STS_045
# Copied 1-27.dcm to ./organized_data/patient_STS_045
# Copied 1-23.dcm to ./organized_data/patient_STS_045
# Copied 1-21.dcm to ./organized_data/patient_STS_045
# Copied 1-11.dcm to ./organized_data/patient_STS_045
# Copied 1-13.dcm to ./organized_data/patient_STS_045
# Copied 1-09.dcm to ./organized_data/patient_STS_045
# Copied 1-24.dcm to ./organized_data/patient_STS_045
# Copied 1-17.dcm to ./organized_data/patient_STS_045
# Copied 1-32.dcm to ./organized_data/patient_STS_045
# Copied 1-36.dcm to ./organized_data/patient_STS_045
# Copied 1-41.dcm to ./organized_data/patient_STS_045
# Copied 1-30.dcm to ./organized_data/patient_STS_045
# Copied 1-38.dcm to ./organized_data/patient_STS_045
# Copied 1-18.dcm to ./organized_data/patient_STS_045
# Copied 1-28.dcm to ./organized_data/patient_STS_045
# Copied 1-45.dcm to ./organized_data/patient_STS_045
# Copied 1-40.dcm to ./organized_data/patient_STS_045
# Copied 1-25.dcm to ./organized_data/patient_STS_045
# Copied 1-12.dcm to ./organized_data/patient_STS_045
# Copied 1-07.dcm to ./organized_data/patient_STS_045
# Copied 1-34.dcm to ./organized_data/patient_STS_045
# Copied 1-05.dcm to ./organized_data/patient_STS_045
# Copied 1-26.dcm to ./organized_data/patient_STS_045
# Copied 1-31.dcm to ./organized_data/patient_STS_045
# Copied 1-01.dcm to ./organized_data/patient_STS_045
# Copied 1-39.dcm to ./organized_data/patient_STS_045
# Copied 1-37.dcm to ./organized_data/patient_STS_045
# Copied 1-35.dcm to ./organized_data/patient_STS_045
# Copied 1-44.dcm to ./organized_data/patient_STS_010
# Copied 1-46.dcm to ./organized_data/patient_STS_010
# Copied 1-19.dcm to ./organized_data/patient_STS_010
# Copied 1-29.dcm to ./organized_data/patient_STS_010
# Copied 1-42.dcm to ./organized_data/patient_STS_010
# Copied 1-20.dcm to ./organized_data/patient_STS_010
# Copied 1-33.dcm to ./organized_data/patient_STS_010
# Copied 1-16.dcm to ./organized_data/patient_STS_010
# Copied 1-22.dcm to ./organized_data/patient_STS_010
# Copied 1-06.dcm to ./organized_data/patient_STS_010
# Copied 1-14.dcm to ./organized_data/patient_STS_010
# Copied 1-03.dcm to ./organized_data/patient_STS_010
# Copied 1-10.dcm to ./organized_data/patient_STS_010
# Copied 1-43.dcm to ./organized_data/patient_STS_010
# Copied 1-15.dcm to ./organized_data/patient_STS_010
# Copied 1-02.dcm to ./organized_data/patient_STS_010
# Copied 1-04.dcm to ./organized_data/patient_STS_010
# Copied 1-08.dcm to ./organized_data/patient_STS_010
# Copied 1-27.dcm to ./organized_data/patient_STS_010
# Copied 1-23.dcm to ./organized_data/patient_STS_010
# Copied 1-21.dcm to ./organized_data/patient_STS_010
# Copied 1-11.dcm to ./organized_data/patient_STS_010
# Copied 1-13.dcm to ./organized_data/patient_STS_010
# Copied 1-09.dcm to ./organized_data/patient_STS_010
# Copied 1-24.dcm to ./organized_data/patient_STS_010
# Copied 1-17.dcm to ./organized_data/patient_STS_010
# Copied 1-32.dcm to ./organized_data/patient_STS_010
# Copied 1-36.dcm to ./organized_data/patient_STS_010
# Copied 1-41.dcm to ./organized_data/patient_STS_010
# Copied 1-30.dcm to ./organized_data/patient_STS_010
# Copied 1-38.dcm to ./organized_data/patient_STS_010
# Copied 1-18.dcm to ./organized_data/patient_STS_010
# Copied 1-28.dcm to ./organized_data/patient_STS_010
# Copied 1-47.dcm to ./organized_data/patient_STS_010
# Copied 1-45.dcm to ./organized_data/patient_STS_010
# Copied 1-40.dcm to ./organized_data/patient_STS_010
# Copied 1-25.dcm to ./organized_data/patient_STS_010
# Copied 1-12.dcm to ./organized_data/patient_STS_010
# Copied 1-48.dcm to ./organized_data/patient_STS_010
# Copied 1-07.dcm to ./organized_data/patient_STS_010
# Copied 1-34.dcm to ./organized_data/patient_STS_010
# Copied 1-05.dcm to ./organized_data/patient_STS_010
# Copied 1-26.dcm to ./organized_data/patient_STS_010
# Copied 1-31.dcm to ./organized_data/patient_STS_010
# Copied 1-01.dcm to ./organized_data/patient_STS_010
# Copied 1-39.dcm to ./organized_data/patient_STS_010
# Copied 1-37.dcm to ./organized_data/patient_STS_010
# Copied 1-35.dcm to ./organized_data/patient_STS_010
# Copied 1-44.dcm to ./organized_data/patient_STS_006
# Copied 1-19.dcm to ./organized_data/patient_STS_006
# Copied 1-29.dcm to ./organized_data/patient_STS_006
# Copied 1-42.dcm to ./organized_data/patient_STS_006
# Copied 1-20.dcm to ./organized_data/patient_STS_006
# Copied 1-33.dcm to ./organized_data/patient_STS_006
# Copied 1-16.dcm to ./organized_data/patient_STS_006
# Copied 1-22.dcm to ./organized_data/patient_STS_006
# Copied 1-06.dcm to ./organized_data/patient_STS_006
# Copied 1-14.dcm to ./organized_data/patient_STS_006
# Copied 1-03.dcm to ./organized_data/patient_STS_006
# Copied 1-10.dcm to ./organized_data/patient_STS_006
# Copied 1-43.dcm to ./organized_data/patient_STS_006
# Copied 1-15.dcm to ./organized_data/patient_STS_006
# Copied 1-02.dcm to ./organized_data/patient_STS_006
# Copied 1-04.dcm to ./organized_data/patient_STS_006
# Copied 1-08.dcm to ./organized_data/patient_STS_006
# Copied 1-27.dcm to ./organized_data/patient_STS_006
# Copied 1-23.dcm to ./organized_data/patient_STS_006
# Copied 1-21.dcm to ./organized_data/patient_STS_006
# Copied 1-11.dcm to ./organized_data/patient_STS_006
# Copied 1-13.dcm to ./organized_data/patient_STS_006
# Copied 1-09.dcm to ./organized_data/patient_STS_006
# Copied 1-24.dcm to ./organized_data/patient_STS_006
# Copied 1-17.dcm to ./organized_data/patient_STS_006
# Copied 1-32.dcm to ./organized_data/patient_STS_006
# Copied 1-36.dcm to ./organized_data/patient_STS_006
# Copied 1-41.dcm to ./organized_data/patient_STS_006
# Copied 1-30.dcm to ./organized_data/patient_STS_006
# Copied 1-38.dcm to ./organized_data/patient_STS_006
# Copied 1-18.dcm to ./organized_data/patient_STS_006
# Copied 1-28.dcm to ./organized_data/patient_STS_006
# Copied 1-40.dcm to ./organized_data/patient_STS_006
# Copied 1-25.dcm to ./organized_data/patient_STS_006
# Copied 1-12.dcm to ./organized_data/patient_STS_006
# Copied 1-07.dcm to ./organized_data/patient_STS_006
# Copied 1-34.dcm to ./organized_data/patient_STS_006
# Copied 1-05.dcm to ./organized_data/patient_STS_006
# Copied 1-26.dcm to ./organized_data/patient_STS_006
# Copied 1-31.dcm to ./organized_data/patient_STS_006
# Copied 1-01.dcm to ./organized_data/patient_STS_006
# Copied 1-39.dcm to ./organized_data/patient_STS_006
# Copied 1-37.dcm to ./organized_data/patient_STS_006
# Copied 1-35.dcm to ./organized_data/patient_STS_006
# Copied 1-19.dcm to ./organized_data/patient_STS_005
# Copied 1-29.dcm to ./organized_data/patient_STS_005
# Copied 1-20.dcm to ./organized_data/patient_STS_005
# Copied 1-33.dcm to ./organized_data/patient_STS_005
# Copied 1-16.dcm to ./organized_data/patient_STS_005
# Copied 1-22.dcm to ./organized_data/patient_STS_005
# Copied 1-06.dcm to ./organized_data/patient_STS_005
# Copied 1-14.dcm to ./organized_data/patient_STS_005
# Copied 1-03.dcm to ./organized_data/patient_STS_005
# Copied 1-10.dcm to ./organized_data/patient_STS_005
# Copied 1-15.dcm to ./organized_data/patient_STS_005
# Copied 1-02.dcm to ./organized_data/patient_STS_005
# Copied 1-04.dcm to ./organized_data/patient_STS_005
# Copied 1-08.dcm to ./organized_data/patient_STS_005
# Copied 1-27.dcm to ./organized_data/patient_STS_005
# Copied 1-23.dcm to ./organized_data/patient_STS_005
# Copied 1-21.dcm to ./organized_data/patient_STS_005
# Copied 1-11.dcm to ./organized_data/patient_STS_005
# Copied 1-13.dcm to ./organized_data/patient_STS_005
# Copied 1-09.dcm to ./organized_data/patient_STS_005
# Copied 1-24.dcm to ./organized_data/patient_STS_005
# Copied 1-17.dcm to ./organized_data/patient_STS_005
# Copied 1-32.dcm to ./organized_data/patient_STS_005
# Copied 1-30.dcm to ./organized_data/patient_STS_005
# Copied 1-18.dcm to ./organized_data/patient_STS_005
# Copied 1-28.dcm to ./organized_data/patient_STS_005
# Copied 1-25.dcm to ./organized_data/patient_STS_005
# Copied 1-12.dcm to ./organized_data/patient_STS_005
# Copied 1-07.dcm to ./organized_data/patient_STS_005
# Copied 1-05.dcm to ./organized_data/patient_STS_005
# Copied 1-26.dcm to ./organized_data/patient_STS_005
# Copied 1-31.dcm to ./organized_data/patient_STS_005
# Copied 1-01.dcm to ./organized_data/patient_STS_005
# Copied 1-68.dcm to ./organized_data/patient_STS_044
# Copied 1-44.dcm to ./organized_data/patient_STS_044
# Copied 1-46.dcm to ./organized_data/patient_STS_044
# Copied 1-19.dcm to ./organized_data/patient_STS_044
# Copied 1-29.dcm to ./organized_data/patient_STS_044
# Copied 1-42.dcm to ./organized_data/patient_STS_044
# Copied 1-49.dcm to ./organized_data/patient_STS_044
# Copied 1-20.dcm to ./organized_data/patient_STS_044
# Copied 1-59.dcm to ./organized_data/patient_STS_044
# Copied 1-65.dcm to ./organized_data/patient_STS_044
# Copied 1-67.dcm to ./organized_data/patient_STS_044
# Copied 1-55.dcm to ./organized_data/patient_STS_044
# Copied 1-33.dcm to ./organized_data/patient_STS_044
# Copied 1-16.dcm to ./organized_data/patient_STS_044
# Copied 1-22.dcm to ./organized_data/patient_STS_044
# Copied 1-06.dcm to ./organized_data/patient_STS_044
# Copied 1-14.dcm to ./organized_data/patient_STS_044
# Copied 1-03.dcm to ./organized_data/patient_STS_044
# Copied 1-10.dcm to ./organized_data/patient_STS_044
# Copied 1-43.dcm to ./organized_data/patient_STS_044
# Copied 1-15.dcm to ./organized_data/patient_STS_044
# Copied 1-02.dcm to ./organized_data/patient_STS_044
# Copied 1-04.dcm to ./organized_data/patient_STS_044
# Copied 1-57.dcm to ./organized_data/patient_STS_044
# Copied 1-08.dcm to ./organized_data/patient_STS_044
# Copied 1-27.dcm to ./organized_data/patient_STS_044
# Copied 1-23.dcm to ./organized_data/patient_STS_044
# Copied 1-21.dcm to ./organized_data/patient_STS_044
# Copied 1-11.dcm to ./organized_data/patient_STS_044
# Copied 1-66.dcm to ./organized_data/patient_STS_044
# Copied 1-56.dcm to ./organized_data/patient_STS_044
# Copied 1-52.dcm to ./organized_data/patient_STS_044
# Copied 1-51.dcm to ./organized_data/patient_STS_044
# Copied 1-50.dcm to ./organized_data/patient_STS_044
# Copied 1-13.dcm to ./organized_data/patient_STS_044
# Copied 1-09.dcm to ./organized_data/patient_STS_044
# Copied 1-63.dcm to ./organized_data/patient_STS_044
# Copied 1-24.dcm to ./organized_data/patient_STS_044
# Copied 1-17.dcm to ./organized_data/patient_STS_044
# Copied 1-32.dcm to ./organized_data/patient_STS_044
# Copied 1-62.dcm to ./organized_data/patient_STS_044
# Copied 1-36.dcm to ./organized_data/patient_STS_044
# Copied 1-41.dcm to ./organized_data/patient_STS_044
# Copied 1-30.dcm to ./organized_data/patient_STS_044
# Copied 1-38.dcm to ./organized_data/patient_STS_044
# Copied 1-18.dcm to ./organized_data/patient_STS_044
# Copied 1-28.dcm to ./organized_data/patient_STS_044
# Copied 1-47.dcm to ./organized_data/patient_STS_044
# Copied 1-45.dcm to ./organized_data/patient_STS_044
# Copied 1-58.dcm to ./organized_data/patient_STS_044
# Copied 1-60.dcm to ./organized_data/patient_STS_044
# Copied 1-40.dcm to ./organized_data/patient_STS_044
# Copied 1-25.dcm to ./organized_data/patient_STS_044
# Copied 1-61.dcm to ./organized_data/patient_STS_044
# Copied 1-12.dcm to ./organized_data/patient_STS_044
# Copied 1-48.dcm to ./organized_data/patient_STS_044
# Copied 1-64.dcm to ./organized_data/patient_STS_044
# Copied 1-07.dcm to ./organized_data/patient_STS_044
# Copied 1-54.dcm to ./organized_data/patient_STS_044
# Copied 1-34.dcm to ./organized_data/patient_STS_044
# Copied 1-05.dcm to ./organized_data/patient_STS_044
# Copied 1-26.dcm to ./organized_data/patient_STS_044
# Copied 1-31.dcm to ./organized_data/patient_STS_044
# Copied 1-01.dcm to ./organized_data/patient_STS_044
# Copied 1-53.dcm to ./organized_data/patient_STS_044
# Copied 1-39.dcm to ./organized_data/patient_STS_044
# Copied 1-69.dcm to ./organized_data/patient_STS_044
# Copied 1-37.dcm to ./organized_data/patient_STS_044
# Copied 1-35.dcm to ./organized_data/patient_STS_044
# Copied 1-19.dcm to ./organized_data/patient_STS_005
# Copied 1-29.dcm to ./organized_data/patient_STS_005
# Copied 1-20.dcm to ./organized_data/patient_STS_005
# Copied 1-33.dcm to ./organized_data/patient_STS_005
# Copied 1-16.dcm to ./organized_data/patient_STS_005
# Copied 1-22.dcm to ./organized_data/patient_STS_005
# Copied 1-06.dcm to ./organized_data/patient_STS_005
# Copied 1-14.dcm to ./organized_data/patient_STS_005
# Copied 1-03.dcm to ./organized_data/patient_STS_005
# Copied 1-10.dcm to ./organized_data/patient_STS_005
# Copied 1-15.dcm to ./organized_data/patient_STS_005
# Copied 1-02.dcm to ./organized_data/patient_STS_005
# Copied 1-04.dcm to ./organized_data/patient_STS_005
# Copied 1-08.dcm to ./organized_data/patient_STS_005
# Copied 1-27.dcm to ./organized_data/patient_STS_005
# Copied 1-23.dcm to ./organized_data/patient_STS_005
# Copied 1-21.dcm to ./organized_data/patient_STS_005
# Copied 1-11.dcm to ./organized_data/patient_STS_005
# Copied 1-13.dcm to ./organized_data/patient_STS_005
# Copied 1-09.dcm to ./organized_data/patient_STS_005
# Copied 1-24.dcm to ./organized_data/patient_STS_005
# Copied 1-17.dcm to ./organized_data/patient_STS_005
# Copied 1-32.dcm to ./organized_data/patient_STS_005
# Copied 1-30.dcm to ./organized_data/patient_STS_005
# Copied 1-18.dcm to ./organized_data/patient_STS_005
# Copied 1-28.dcm to ./organized_data/patient_STS_005
# Copied 1-25.dcm to ./organized_data/patient_STS_005
# Copied 1-12.dcm to ./organized_data/patient_STS_005
# Copied 1-07.dcm to ./organized_data/patient_STS_005
# Copied 1-05.dcm to ./organized_data/patient_STS_005
# Copied 1-26.dcm to ./organized_data/patient_STS_005
# Copied 1-31.dcm to ./organized_data/patient_STS_005
# Copied 1-01.dcm to ./organized_data/patient_STS_005
# Copied 1-44.dcm to ./organized_data/patient_STS_012
# Copied 1-46.dcm to ./organized_data/patient_STS_012
# Copied 1-19.dcm to ./organized_data/patient_STS_012
# Copied 1-29.dcm to ./organized_data/patient_STS_012
# Copied 1-42.dcm to ./organized_data/patient_STS_012
# Copied 1-49.dcm to ./organized_data/patient_STS_012
# Copied 1-20.dcm to ./organized_data/patient_STS_012
# Copied 1-33.dcm to ./organized_data/patient_STS_012
# Copied 1-16.dcm to ./organized_data/patient_STS_012
# Copied 1-22.dcm to ./organized_data/patient_STS_012
# Copied 1-06.dcm to ./organized_data/patient_STS_012
# Copied 1-14.dcm to ./organized_data/patient_STS_012
# Copied 1-03.dcm to ./organized_data/patient_STS_012
# Copied 1-10.dcm to ./organized_data/patient_STS_012
# Copied 1-43.dcm to ./organized_data/patient_STS_012
# Copied 1-15.dcm to ./organized_data/patient_STS_012
# Copied 1-02.dcm to ./organized_data/patient_STS_012
# Copied 1-04.dcm to ./organized_data/patient_STS_012
# Copied 1-08.dcm to ./organized_data/patient_STS_012
# Copied 1-27.dcm to ./organized_data/patient_STS_012
# Copied 1-23.dcm to ./organized_data/patient_STS_012
# Copied 1-21.dcm to ./organized_data/patient_STS_012
# Copied 1-11.dcm to ./organized_data/patient_STS_012
# Copied 1-50.dcm to ./organized_data/patient_STS_012
# Copied 1-13.dcm to ./organized_data/patient_STS_012
# Copied 1-09.dcm to ./organized_data/patient_STS_012
# Copied 1-24.dcm to ./organized_data/patient_STS_012
# Copied 1-17.dcm to ./organized_data/patient_STS_012
# Copied 1-32.dcm to ./organized_data/patient_STS_012
# Copied 1-36.dcm to ./organized_data/patient_STS_012
# Copied 1-41.dcm to ./organized_data/patient_STS_012
# Copied 1-30.dcm to ./organized_data/patient_STS_012
# Copied 1-38.dcm to ./organized_data/patient_STS_012
# Copied 1-18.dcm to ./organized_data/patient_STS_012
# Copied 1-28.dcm to ./organized_data/patient_STS_012
# Copied 1-47.dcm to ./organized_data/patient_STS_012
# Copied 1-45.dcm to ./organized_data/patient_STS_012
# Copied 1-40.dcm to ./organized_data/patient_STS_012
# Copied 1-25.dcm to ./organized_data/patient_STS_012
# Copied 1-12.dcm to ./organized_data/patient_STS_012
# Copied 1-48.dcm to ./organized_data/patient_STS_012
# Copied 1-07.dcm to ./organized_data/patient_STS_012
# Copied 1-34.dcm to ./organized_data/patient_STS_012
# Copied 1-05.dcm to ./organized_data/patient_STS_012
# Copied 1-26.dcm to ./organized_data/patient_STS_012
# Copied 1-31.dcm to ./organized_data/patient_STS_012
# Copied 1-01.dcm to ./organized_data/patient_STS_012
# Copied 1-39.dcm to ./organized_data/patient_STS_012
# Copied 1-37.dcm to ./organized_data/patient_STS_012
# Copied 1-35.dcm to ./organized_data/patient_STS_012
# Copied 1-44.dcm to ./organized_data/patient_STS_010
# Copied 1-46.dcm to ./organized_data/patient_STS_010
# Copied 1-19.dcm to ./organized_data/patient_STS_010
# Copied 1-29.dcm to ./organized_data/patient_STS_010
# Copied 1-42.dcm to ./organized_data/patient_STS_010
# Copied 1-20.dcm to ./organized_data/patient_STS_010
# Copied 1-33.dcm to ./organized_data/patient_STS_010
# Copied 1-16.dcm to ./organized_data/patient_STS_010
# Copied 1-22.dcm to ./organized_data/patient_STS_010
# Copied 1-06.dcm to ./organized_data/patient_STS_010
# Copied 1-14.dcm to ./organized_data/patient_STS_010
# Copied 1-03.dcm to ./organized_data/patient_STS_010
# Copied 1-10.dcm to ./organized_data/patient_STS_010
# Copied 1-43.dcm to ./organized_data/patient_STS_010
# Copied 1-15.dcm to ./organized_data/patient_STS_010
# Copied 1-02.dcm to ./organized_data/patient_STS_010
# Copied 1-04.dcm to ./organized_data/patient_STS_010
# Copied 1-08.dcm to ./organized_data/patient_STS_010
# Copied 1-27.dcm to ./organized_data/patient_STS_010
# Copied 1-23.dcm to ./organized_data/patient_STS_010
# Copied 1-21.dcm to ./organized_data/patient_STS_010
# Copied 1-11.dcm to ./organized_data/patient_STS_010
# Copied 1-13.dcm to ./organized_data/patient_STS_010
# Copied 1-09.dcm to ./organized_data/patient_STS_010
# Copied 1-24.dcm to ./organized_data/patient_STS_010
# Copied 1-17.dcm to ./organized_data/patient_STS_010
# Copied 1-32.dcm to ./organized_data/patient_STS_010
# Copied 1-36.dcm to ./organized_data/patient_STS_010
# Copied 1-41.dcm to ./organized_data/patient_STS_010
# Copied 1-30.dcm to ./organized_data/patient_STS_010
# Copied 1-38.dcm to ./organized_data/patient_STS_010
# Copied 1-18.dcm to ./organized_data/patient_STS_010
# Copied 1-28.dcm to ./organized_data/patient_STS_010
# Copied 1-47.dcm to ./organized_data/patient_STS_010
# Copied 1-45.dcm to ./organized_data/patient_STS_010
# Copied 1-40.dcm to ./organized_data/patient_STS_010
# Copied 1-25.dcm to ./organized_data/patient_STS_010
# Copied 1-12.dcm to ./organized_data/patient_STS_010
# Copied 1-48.dcm to ./organized_data/patient_STS_010
# Copied 1-07.dcm to ./organized_data/patient_STS_010
# Copied 1-34.dcm to ./organized_data/patient_STS_010
# Copied 1-05.dcm to ./organized_data/patient_STS_010
# Copied 1-26.dcm to ./organized_data/patient_STS_010
# Copied 1-31.dcm to ./organized_data/patient_STS_010
# Copied 1-01.dcm to ./organized_data/patient_STS_010
# Copied 1-39.dcm to ./organized_data/patient_STS_010
# Copied 1-37.dcm to ./organized_data/patient_STS_010
# Copied 1-35.dcm to ./organized_data/patient_STS_010
# Copied 1-44.dcm to ./organized_data/patient_STS_012
# Copied 1-46.dcm to ./organized_data/patient_STS_012
# Copied 1-19.dcm to ./organized_data/patient_STS_012
# Copied 1-29.dcm to ./organized_data/patient_STS_012
# Copied 1-42.dcm to ./organized_data/patient_STS_012
# Copied 1-49.dcm to ./organized_data/patient_STS_012
# Copied 1-20.dcm to ./organized_data/patient_STS_012
# Copied 1-33.dcm to ./organized_data/patient_STS_012
# Copied 1-16.dcm to ./organized_data/patient_STS_012
# Copied 1-22.dcm to ./organized_data/patient_STS_012
# Copied 1-06.dcm to ./organized_data/patient_STS_012
# Copied 1-14.dcm to ./organized_data/patient_STS_012
# Copied 1-03.dcm to ./organized_data/patient_STS_012
# Copied 1-10.dcm to ./organized_data/patient_STS_012
# Copied 1-43.dcm to ./organized_data/patient_STS_012
# Copied 1-15.dcm to ./organized_data/patient_STS_012
# Copied 1-02.dcm to ./organized_data/patient_STS_012
# Copied 1-04.dcm to ./organized_data/patient_STS_012
# Copied 1-08.dcm to ./organized_data/patient_STS_012
# Copied 1-27.dcm to ./organized_data/patient_STS_012
# Copied 1-23.dcm to ./organized_data/patient_STS_012
# Copied 1-21.dcm to ./organized_data/patient_STS_012
# Copied 1-11.dcm to ./organized_data/patient_STS_012
# Copied 1-50.dcm to ./organized_data/patient_STS_012
# Copied 1-13.dcm to ./organized_data/patient_STS_012
# Copied 1-09.dcm to ./organized_data/patient_STS_012
# Copied 1-24.dcm to ./organized_data/patient_STS_012
# Copied 1-17.dcm to ./organized_data/patient_STS_012
# Copied 1-32.dcm to ./organized_data/patient_STS_012
# Copied 1-36.dcm to ./organized_data/patient_STS_012
# Copied 1-41.dcm to ./organized_data/patient_STS_012
# Copied 1-30.dcm to ./organized_data/patient_STS_012
# Copied 1-38.dcm to ./organized_data/patient_STS_012
# Copied 1-18.dcm to ./organized_data/patient_STS_012
# Copied 1-28.dcm to ./organized_data/patient_STS_012
# Copied 1-47.dcm to ./organized_data/patient_STS_012
# Copied 1-45.dcm to ./organized_data/patient_STS_012
# Copied 1-40.dcm to ./organized_data/patient_STS_012
# Copied 1-25.dcm to ./organized_data/patient_STS_012
# Copied 1-12.dcm to ./organized_data/patient_STS_012
# Copied 1-48.dcm to ./organized_data/patient_STS_012
# Copied 1-07.dcm to ./organized_data/patient_STS_012
# Copied 1-34.dcm to ./organized_data/patient_STS_012
# Copied 1-05.dcm to ./organized_data/patient_STS_012
# Copied 1-26.dcm to ./organized_data/patient_STS_012
# Copied 1-31.dcm to ./organized_data/patient_STS_012
# Copied 1-01.dcm to ./organized_data/patient_STS_012
# Copied 1-39.dcm to ./organized_data/patient_STS_012
# Copied 1-37.dcm to ./organized_data/patient_STS_012
# Copied 1-35.dcm to ./organized_data/patient_STS_012
# Copied 1-44.dcm to ./organized_data/patient_STS_006
# Copied 1-19.dcm to ./organized_data/patient_STS_006
# Copied 1-29.dcm to ./organized_data/patient_STS_006
# Copied 1-42.dcm to ./organized_data/patient_STS_006
# Copied 1-20.dcm to ./organized_data/patient_STS_006
# Copied 1-33.dcm to ./organized_data/patient_STS_006
# Copied 1-16.dcm to ./organized_data/patient_STS_006
# Copied 1-22.dcm to ./organized_data/patient_STS_006
# Copied 1-06.dcm to ./organized_data/patient_STS_006
# Copied 1-14.dcm to ./organized_data/patient_STS_006
# Copied 1-03.dcm to ./organized_data/patient_STS_006
# Copied 1-10.dcm to ./organized_data/patient_STS_006
# Copied 1-43.dcm to ./organized_data/patient_STS_006
# Copied 1-15.dcm to ./organized_data/patient_STS_006
# Copied 1-02.dcm to ./organized_data/patient_STS_006
# Copied 1-04.dcm to ./organized_data/patient_STS_006
# Copied 1-08.dcm to ./organized_data/patient_STS_006
# Copied 1-27.dcm to ./organized_data/patient_STS_006
# Copied 1-23.dcm to ./organized_data/patient_STS_006
# Copied 1-21.dcm to ./organized_data/patient_STS_006
# Copied 1-11.dcm to ./organized_data/patient_STS_006
# Copied 1-13.dcm to ./organized_data/patient_STS_006
# Copied 1-09.dcm to ./organized_data/patient_STS_006
# Copied 1-24.dcm to ./organized_data/patient_STS_006
# Copied 1-17.dcm to ./organized_data/patient_STS_006
# Copied 1-32.dcm to ./organized_data/patient_STS_006
# Copied 1-36.dcm to ./organized_data/patient_STS_006
# Copied 1-41.dcm to ./organized_data/patient_STS_006
# Copied 1-30.dcm to ./organized_data/patient_STS_006
# Copied 1-38.dcm to ./organized_data/patient_STS_006
# Copied 1-18.dcm to ./organized_data/patient_STS_006
# Copied 1-28.dcm to ./organized_data/patient_STS_006
# Copied 1-40.dcm to ./organized_data/patient_STS_006
# Copied 1-25.dcm to ./organized_data/patient_STS_006
# Copied 1-12.dcm to ./organized_data/patient_STS_006
# Copied 1-07.dcm to ./organized_data/patient_STS_006
# Copied 1-34.dcm to ./organized_data/patient_STS_006
# Copied 1-05.dcm to ./organized_data/patient_STS_006
# Copied 1-26.dcm to ./organized_data/patient_STS_006
# Copied 1-31.dcm to ./organized_data/patient_STS_006
# Copied 1-01.dcm to ./organized_data/patient_STS_006
# Copied 1-39.dcm to ./organized_data/patient_STS_006
# Copied 1-37.dcm to ./organized_data/patient_STS_006
# Copied 1-35.dcm to ./organized_data/patient_STS_006
# Copied 1-44.dcm to ./organized_data/patient_STS_045
# Copied 1-19.dcm to ./organized_data/patient_STS_045
# Copied 1-29.dcm to ./organized_data/patient_STS_045
# Copied 1-42.dcm to ./organized_data/patient_STS_045
# Copied 1-20.dcm to ./organized_data/patient_STS_045
# Copied 1-33.dcm to ./organized_data/patient_STS_045
# Copied 1-16.dcm to ./organized_data/patient_STS_045
# Copied 1-22.dcm to ./organized_data/patient_STS_045
# Copied 1-06.dcm to ./organized_data/patient_STS_045
# Copied 1-14.dcm to ./organized_data/patient_STS_045
# Copied 1-03.dcm to ./organized_data/patient_STS_045
# Copied 1-10.dcm to ./organized_data/patient_STS_045
# Copied 1-43.dcm to ./organized_data/patient_STS_045
# Copied 1-15.dcm to ./organized_data/patient_STS_045
# Copied 1-02.dcm to ./organized_data/patient_STS_045
# Copied 1-04.dcm to ./organized_data/patient_STS_045
# Copied 1-08.dcm to ./organized_data/patient_STS_045
# Copied 1-27.dcm to ./organized_data/patient_STS_045
# Copied 1-23.dcm to ./organized_data/patient_STS_045
# Copied 1-21.dcm to ./organized_data/patient_STS_045
# Copied 1-11.dcm to ./organized_data/patient_STS_045
# Copied 1-13.dcm to ./organized_data/patient_STS_045
# Copied 1-09.dcm to ./organized_data/patient_STS_045
# Copied 1-24.dcm to ./organized_data/patient_STS_045
# Copied 1-17.dcm to ./organized_data/patient_STS_045
# Copied 1-32.dcm to ./organized_data/patient_STS_045
# Copied 1-36.dcm to ./organized_data/patient_STS_045
# Copied 1-41.dcm to ./organized_data/patient_STS_045
# Copied 1-30.dcm to ./organized_data/patient_STS_045
# Copied 1-38.dcm to ./organized_data/patient_STS_045
# Copied 1-18.dcm to ./organized_data/patient_STS_045
# Copied 1-28.dcm to ./organized_data/patient_STS_045
# Copied 1-45.dcm to ./organized_data/patient_STS_045
# Copied 1-40.dcm to ./organized_data/patient_STS_045
# Copied 1-25.dcm to ./organized_data/patient_STS_045
# Copied 1-12.dcm to ./organized_data/patient_STS_045
# Copied 1-07.dcm to ./organized_data/patient_STS_045
# Copied 1-34.dcm to ./organized_data/patient_STS_045
# Copied 1-05.dcm to ./organized_data/patient_STS_045
# Copied 1-26.dcm to ./organized_data/patient_STS_045
# Copied 1-31.dcm to ./organized_data/patient_STS_045
# Copied 1-01.dcm to ./organized_data/patient_STS_045
# Copied 1-39.dcm to ./organized_data/patient_STS_045
# Copied 1-37.dcm to ./organized_data/patient_STS_045
# Copied 1-35.dcm to ./organized_data/patient_STS_045

# %%
import cv2, numpy as np

def dicom_to_png(input_dir, output_dir):
    # Ensure output directories exist
    os.makedirs(output_dir, exist_ok=True)

    # Loop over patients
    for patient_folder in os.listdir(input_dir):
        patient_path = os.path.join(input_dir, patient_folder)

        # Create output directory for the patient
        patient_output_dir = os.path.join(output_dir, patient_folder)
        os.makedirs(patient_output_dir, exist_ok=True)

        for dicom_file in os.listdir(patient_path):
            if dicom_file.endswith(".dcm"):
                dicom_path = os.path.join(patient_path, dicom_file)
                dicom_data = pydicom.dcmread(dicom_path)
                pixel_array = dicom_data.pixel_array

                # Normalize image to 0-255 for PNG saving
                img = cv2.normalize(pixel_array, None, 0, 255, cv2.NORM_MINMAX).astype(np.uint8)

                # Create the PNG filename
                png_filename = dicom_file.replace(".dcm", ".png")

                # Save as PNG
                cv2.imwrite(os.path.join(patient_output_dir, png_filename), img)
                print(f"Saved {png_filename} in {patient_output_dir}")

# Paths to organized DICOM data and desired PNG output
organized_dicom_dir = "/content/organized_data"
png_output_dir = "./organized_data_PNG"

dicom_to_png(organized_dicom_dir, png_output_dir)
# Out:
# Saved 1-44.png in ./organized_data_PNG/patient_STS_010
# Saved 1-46.png in ./organized_data_PNG/patient_STS_010
# Saved 1-19.png in ./organized_data_PNG/patient_STS_010
# Saved 1-29.png in ./organized_data_PNG/patient_STS_010
# Saved 1-42.png in ./organized_data_PNG/patient_STS_010
# Saved 1-20.png in ./organized_data_PNG/patient_STS_010
# Saved 1-33.png in ./organized_data_PNG/patient_STS_010
# Saved 1-16.png in ./organized_data_PNG/patient_STS_010
# Saved 1-22.png in ./organized_data_PNG/patient_STS_010
# Saved 1-06.png in ./organized_data_PNG/patient_STS_010
# Saved 1-14.png in ./organized_data_PNG/patient_STS_010
# Saved 1-03.png in ./organized_data_PNG/patient_STS_010
# Saved 1-10.png in ./organized_data_PNG/patient_STS_010
# Saved 1-43.png in ./organized_data_PNG/patient_STS_010
# Saved 1-15.png in ./organized_data_PNG/patient_STS_010
# Saved 1-02.png in ./organized_data_PNG/patient_STS_010
# Saved 1-04.png in ./organized_data_PNG/patient_STS_010
# Saved 1-08.png in ./organized_data_PNG/patient_STS_010
# Saved 1-27.png in ./organized_data_PNG/patient_STS_010
# Saved 1-23.png in ./organized_data_PNG/patient_STS_010
# Saved 1-21.png in ./organized_data_PNG/patient_STS_010
# Saved 1-11.png in ./organized_data_PNG/patient_STS_010
# Saved 1-13.png in ./organized_data_PNG/patient_STS_010
# Saved 1-09.png in ./organized_data_PNG/patient_STS_010
# Saved 1-24.png in ./organized_data_PNG/patient_STS_010
# Saved 1-17.png in ./organized_data_PNG/patient_STS_010
# Saved 1-32.png in ./organized_data_PNG/patient_STS_010
# Saved 1-36.png in ./organized_data_PNG/patient_STS_010
# Saved 1-41.png in ./organized_data_PNG/patient_STS_010
# Saved 1-30.png in ./organized_data_PNG/patient_STS_010
# Saved 1-38.png in ./organized_data_PNG/patient_STS_010
# Saved 1-18.png in ./organized_data_PNG/patient_STS_010
# Saved 1-28.png in ./organized_data_PNG/patient_STS_010
# Saved 1-47.png in ./organized_data_PNG/patient_STS_010
# Saved 1-45.png in ./organized_data_PNG/patient_STS_010
# Saved 1-40.png in ./organized_data_PNG/patient_STS_010
# Saved 1-25.png in ./organized_data_PNG/patient_STS_010
# Saved 1-12.png in ./organized_data_PNG/patient_STS_010
# Saved 1-48.png in ./organized_data_PNG/patient_STS_010
# Saved 1-07.png in ./organized_data_PNG/patient_STS_010
# Saved 1-34.png in ./organized_data_PNG/patient_STS_010
# Saved 1-05.png in ./organized_data_PNG/patient_STS_010
# Saved 1-26.png in ./organized_data_PNG/patient_STS_010
# Saved 1-31.png in ./organized_data_PNG/patient_STS_010
# Saved 1-01.png in ./organized_data_PNG/patient_STS_010
# Saved 1-39.png in ./organized_data_PNG/patient_STS_010
# Saved 1-37.png in ./organized_data_PNG/patient_STS_010
# Saved 1-35.png in ./organized_data_PNG/patient_STS_010
# Saved 1-68.png in ./organized_data_PNG/patient_STS_044
# Saved 1-44.png in ./organized_data_PNG/patient_STS_044
# Saved 1-46.png in ./organized_data_PNG/patient_STS_044
# Saved 1-19.png in ./organized_data_PNG/patient_STS_044
# Saved 1-29.png in ./organized_data_PNG/patient_STS_044
# Saved 1-42.png in ./organized_data_PNG/patient_STS_044
# Saved 1-49.png in ./organized_data_PNG/patient_STS_044
# Saved 1-20.png in ./organized_data_PNG/patient_STS_044
# Saved 1-59.png in ./organized_data_PNG/patient_STS_044
# Saved 1-65.png in ./organized_data_PNG/patient_STS_044
# Saved 1-67.png in ./organized_data_PNG/patient_STS_044
# Saved 1-55.png in ./organized_data_PNG/patient_STS_044
# Saved 1-33.png in ./organized_data_PNG/patient_STS_044
# Saved 1-16.png in ./organized_data_PNG/patient_STS_044
# Saved 1-22.png in ./organized_data_PNG/patient_STS_044
# Saved 1-06.png in ./organized_data_PNG/patient_STS_044
# Saved 1-14.png in ./organized_data_PNG/patient_STS_044
# Saved 1-03.png in ./organized_data_PNG/patient_STS_044
# Saved 1-10.png in ./organized_data_PNG/patient_STS_044
# Saved 1-43.png in ./organized_data_PNG/patient_STS_044
# Saved 1-15.png in ./organized_data_PNG/patient_STS_044
# Saved 1-02.png in ./organized_data_PNG/patient_STS_044
# Saved 1-04.png in ./organized_data_PNG/patient_STS_044
# Saved 1-57.png in ./organized_data_PNG/patient_STS_044
# Saved 1-08.png in ./organized_data_PNG/patient_STS_044
# Saved 1-27.png in ./organized_data_PNG/patient_STS_044
# Saved 1-23.png in ./organized_data_PNG/patient_STS_044
# Saved 1-21.png in ./organized_data_PNG/patient_STS_044
# Saved 1-11.png in ./organized_data_PNG/patient_STS_044
# Saved 1-66.png in ./organized_data_PNG/patient_STS_044
# Saved 1-56.png in ./organized_data_PNG/patient_STS_044
# Saved 1-52.png in ./organized_data_PNG/patient_STS_044
# Saved 1-51.png in ./organized_data_PNG/patient_STS_044
# Saved 1-50.png in ./organized_data_PNG/patient_STS_044
# Saved 1-13.png in ./organized_data_PNG/patient_STS_044
# Saved 1-09.png in ./organized_data_PNG/patient_STS_044
# Saved 1-63.png in ./organized_data_PNG/patient_STS_044
# Saved 1-24.png in ./organized_data_PNG/patient_STS_044
# Saved 1-17.png in ./organized_data_PNG/patient_STS_044
# Saved 1-32.png in ./organized_data_PNG/patient_STS_044
# Saved 1-62.png in ./organized_data_PNG/patient_STS_044
# Saved 1-36.png in ./organized_data_PNG/patient_STS_044
# Saved 1-41.png in ./organized_data_PNG/patient_STS_044
# Saved 1-30.png in ./organized_data_PNG/patient_STS_044
# Saved 1-38.png in ./organized_data_PNG/patient_STS_044
# Saved 1-18.png in ./organized_data_PNG/patient_STS_044
# Saved 1-28.png in ./organized_data_PNG/patient_STS_044
# Saved 1-47.png in ./organized_data_PNG/patient_STS_044
# Saved 1-45.png in ./organized_data_PNG/patient_STS_044
# Saved 1-58.png in ./organized_data_PNG/patient_STS_044
# Saved 1-60.png in ./organized_data_PNG/patient_STS_044
# Saved 1-40.png in ./organized_data_PNG/patient_STS_044
# Saved 1-25.png in ./organized_data_PNG/patient_STS_044
# Saved 1-61.png in ./organized_data_PNG/patient_STS_044
# Saved 1-12.png in ./organized_data_PNG/patient_STS_044
# Saved 1-48.png in ./organized_data_PNG/patient_STS_044
# Saved 1-64.png in ./organized_data_PNG/patient_STS_044
# Saved 1-07.png in ./organized_data_PNG/patient_STS_044
# Saved 1-54.png in ./organized_data_PNG/patient_STS_044
# Saved 1-34.png in ./organized_data_PNG/patient_STS_044
# Saved 1-05.png in ./organized_data_PNG/patient_STS_044
# Saved 1-26.png in ./organized_data_PNG/patient_STS_044
# Saved 1-31.png in ./organized_data_PNG/patient_STS_044
# Saved 1-01.png in ./organized_data_PNG/patient_STS_044
# Saved 1-53.png in ./organized_data_PNG/patient_STS_044
# Saved 1-39.png in ./organized_data_PNG/patient_STS_044
# Saved 1-69.png in ./organized_data_PNG/patient_STS_044
# Saved 1-37.png in ./organized_data_PNG/patient_STS_044
# Saved 1-35.png in ./organized_data_PNG/patient_STS_044
# Saved 1-44.png in ./organized_data_PNG/patient_STS_045
# Saved 1-19.png in ./organized_data_PNG/patient_STS_045
# Saved 1-29.png in ./organized_data_PNG/patient_STS_045
# Saved 1-42.png in ./organized_data_PNG/patient_STS_045
# Saved 1-20.png in ./organized_data_PNG/patient_STS_045
# Saved 1-33.png in ./organized_data_PNG/patient_STS_045
# Saved 1-16.png in ./organized_data_PNG/patient_STS_045
# Saved 1-22.png in ./organized_data_PNG/patient_STS_045
# Saved 1-06.png in ./organized_data_PNG/patient_STS_045
# Saved 1-14.png in ./organized_data_PNG/patient_STS_045
# Saved 1-03.png in ./organized_data_PNG/patient_STS_045
# Saved 1-10.png in ./organized_data_PNG/patient_STS_045
# Saved 1-43.png in ./organized_data_PNG/patient_STS_045
# Saved 1-15.png in ./organized_data_PNG/patient_STS_045
# Saved 1-02.png in ./organized_data_PNG/patient_STS_045
# Saved 1-04.png in ./organized_data_PNG/patient_STS_045
# Saved 1-08.png in ./organized_data_PNG/patient_STS_045
# Saved 1-27.png in ./organized_data_PNG/patient_STS_045
# Saved 1-23.png in ./organized_data_PNG/patient_STS_045
# Saved 1-21.png in ./organized_data_PNG/patient_STS_045
# Saved 1-11.png in ./organized_data_PNG/patient_STS_045
# Saved 1-13.png in ./organized_data_PNG/patient_STS_045
# Saved 1-09.png in ./organized_data_PNG/patient_STS_045
# Saved 1-24.png in ./organized_data_PNG/patient_STS_045
# Saved 1-17.png in ./organized_data_PNG/patient_STS_045
# Saved 1-32.png in ./organized_data_PNG/patient_STS_045
# Saved 1-36.png in ./organized_data_PNG/patient_STS_045
# Saved 1-41.png in ./organized_data_PNG/patient_STS_045
# Saved 1-30.png in ./organized_data_PNG/patient_STS_045
# Saved 1-38.png in ./organized_data_PNG/patient_STS_045
# Saved 1-18.png in ./organized_data_PNG/patient_STS_045
# Saved 1-28.png in ./organized_data_PNG/patient_STS_045
# Saved 1-45.png in ./organized_data_PNG/patient_STS_045
# Saved 1-40.png in ./organized_data_PNG/patient_STS_045
# Saved 1-25.png in ./organized_data_PNG/patient_STS_045
# Saved 1-12.png in ./organized_data_PNG/patient_STS_045
# Saved 1-07.png in ./organized_data_PNG/patient_STS_045
# Saved 1-34.png in ./organized_data_PNG/patient_STS_045
# Saved 1-05.png in ./organized_data_PNG/patient_STS_045
# Saved 1-26.png in ./organized_data_PNG/patient_STS_045
# Saved 1-31.png in ./organized_data_PNG/patient_STS_045
# Saved 1-01.png in ./organized_data_PNG/patient_STS_045
# Saved 1-39.png in ./organized_data_PNG/patient_STS_045
# Saved 1-37.png in ./organized_data_PNG/patient_STS_045
# Saved 1-35.png in ./organized_data_PNG/patient_STS_045
# Saved 1-19.png in ./organized_data_PNG/patient_STS_005
# Saved 1-29.png in ./organized_data_PNG/patient_STS_005
# Saved 1-20.png in ./organized_data_PNG/patient_STS_005
# Saved 1-33.png in ./organized_data_PNG/patient_STS_005
# Saved 1-16.png in ./organized_data_PNG/patient_STS_005
# Saved 1-22.png in ./organized_data_PNG/patient_STS_005
# Saved 1-06.png in ./organized_data_PNG/patient_STS_005
# Saved 1-14.png in ./organized_data_PNG/patient_STS_005
# Saved 1-03.png in ./organized_data_PNG/patient_STS_005
# Saved 1-10.png in ./organized_data_PNG/patient_STS_005
# Saved 1-15.png in ./organized_data_PNG/patient_STS_005
# Saved 1-02.png in ./organized_data_PNG/patient_STS_005
# Saved 1-04.png in ./organized_data_PNG/patient_STS_005
# Saved 1-08.png in ./organized_data_PNG/patient_STS_005
# Saved 1-27.png in ./organized_data_PNG/patient_STS_005
# Saved 1-23.png in ./organized_data_PNG/patient_STS_005
# Saved 1-21.png in ./organized_data_PNG/patient_STS_005
# Saved 1-11.png in ./organized_data_PNG/patient_STS_005
# Saved 1-13.png in ./organized_data_PNG/patient_STS_005
# Saved 1-09.png in ./organized_data_PNG/patient_STS_005
# Saved 1-24.png in ./organized_data_PNG/patient_STS_005
# Saved 1-17.png in ./organized_data_PNG/patient_STS_005
# Saved 1-32.png in ./organized_data_PNG/patient_STS_005
# Saved 1-30.png in ./organized_data_PNG/patient_STS_005
# Saved 1-18.png in ./organized_data_PNG/patient_STS_005
# Saved 1-28.png in ./organized_data_PNG/patient_STS_005
# Saved 1-25.png in ./organized_data_PNG/patient_STS_005
# Saved 1-12.png in ./organized_data_PNG/patient_STS_005
# Saved 1-07.png in ./organized_data_PNG/patient_STS_005
# Saved 1-05.png in ./organized_data_PNG/patient_STS_005
# Saved 1-26.png in ./organized_data_PNG/patient_STS_005
# Saved 1-31.png in ./organized_data_PNG/patient_STS_005
# Saved 1-01.png in ./organized_data_PNG/patient_STS_005
# Saved 1-44.png in ./organized_data_PNG/patient_STS_006
# Saved 1-19.png in ./organized_data_PNG/patient_STS_006
# Saved 1-29.png in ./organized_data_PNG/patient_STS_006
# Saved 1-42.png in ./organized_data_PNG/patient_STS_006
# Saved 1-20.png in ./organized_data_PNG/patient_STS_006
# Saved 1-33.png in ./organized_data_PNG/patient_STS_006
# Saved 1-16.png in ./organized_data_PNG/patient_STS_006
# Saved 1-22.png in ./organized_data_PNG/patient_STS_006
# Saved 1-06.png in ./organized_data_PNG/patient_STS_006
# Saved 1-14.png in ./organized_data_PNG/patient_STS_006
# Saved 1-03.png in ./organized_data_PNG/patient_STS_006
# Saved 1-10.png in ./organized_data_PNG/patient_STS_006
# Saved 1-43.png in ./organized_data_PNG/patient_STS_006
# Saved 1-15.png in ./organized_data_PNG/patient_STS_006
# Saved 1-02.png in ./organized_data_PNG/patient_STS_006
# Saved 1-04.png in ./organized_data_PNG/patient_STS_006
# Saved 1-08.png in ./organized_data_PNG/patient_STS_006
# Saved 1-27.png in ./organized_data_PNG/patient_STS_006
# Saved 1-23.png in ./organized_data_PNG/patient_STS_006
# Saved 1-21.png in ./organized_data_PNG/patient_STS_006
# Saved 1-11.png in ./organized_data_PNG/patient_STS_006
# Saved 1-13.png in ./organized_data_PNG/patient_STS_006
# Saved 1-09.png in ./organized_data_PNG/patient_STS_006
# Saved 1-24.png in ./organized_data_PNG/patient_STS_006
# Saved 1-17.png in ./organized_data_PNG/patient_STS_006
# Saved 1-32.png in ./organized_data_PNG/patient_STS_006
# Saved 1-36.png in ./organized_data_PNG/patient_STS_006
# Saved 1-41.png in ./organized_data_PNG/patient_STS_006
# Saved 1-30.png in ./organized_data_PNG/patient_STS_006
# Saved 1-38.png in ./organized_data_PNG/patient_STS_006
# Saved 1-18.png in ./organized_data_PNG/patient_STS_006
# Saved 1-28.png in ./organized_data_PNG/patient_STS_006
# Saved 1-40.png in ./organized_data_PNG/patient_STS_006
# Saved 1-25.png in ./organized_data_PNG/patient_STS_006
# Saved 1-12.png in ./organized_data_PNG/patient_STS_006
# Saved 1-07.png in ./organized_data_PNG/patient_STS_006
# Saved 1-34.png in ./organized_data_PNG/patient_STS_006
# Saved 1-05.png in ./organized_data_PNG/patient_STS_006
# Saved 1-26.png in ./organized_data_PNG/patient_STS_006
# Saved 1-31.png in ./organized_data_PNG/patient_STS_006
# Saved 1-01.png in ./organized_data_PNG/patient_STS_006
# Saved 1-39.png in ./organized_data_PNG/patient_STS_006
# Saved 1-37.png in ./organized_data_PNG/patient_STS_006
# Saved 1-35.png in ./organized_data_PNG/patient_STS_006
# Saved 1-44.png in ./organized_data_PNG/patient_STS_012
# Saved 1-46.png in ./organized_data_PNG/patient_STS_012
# Saved 1-19.png in ./organized_data_PNG/patient_STS_012
# Saved 1-29.png in ./organized_data_PNG/patient_STS_012
# Saved 1-42.png in ./organized_data_PNG/patient_STS_012
# Saved 1-49.png in ./organized_data_PNG/patient_STS_012
# Saved 1-20.png in ./organized_data_PNG/patient_STS_012
# Saved 1-33.png in ./organized_data_PNG/patient_STS_012
# Saved 1-16.png in ./organized_data_PNG/patient_STS_012
# Saved 1-22.png in ./organized_data_PNG/patient_STS_012
# Saved 1-06.png in ./organized_data_PNG/patient_STS_012
# Saved 1-14.png in ./organized_data_PNG/patient_STS_012
# Saved 1-03.png in ./organized_data_PNG/patient_STS_012
# Saved 1-10.png in ./organized_data_PNG/patient_STS_012
# Saved 1-43.png in ./organized_data_PNG/patient_STS_012
# Saved 1-15.png in ./organized_data_PNG/patient_STS_012
# Saved 1-02.png in ./organized_data_PNG/patient_STS_012
# Saved 1-04.png in ./organized_data_PNG/patient_STS_012
# Saved 1-08.png in ./organized_data_PNG/patient_STS_012
# Saved 1-27.png in ./organized_data_PNG/patient_STS_012
# Saved 1-23.png in ./organized_data_PNG/patient_STS_012
# Saved 1-21.png in ./organized_data_PNG/patient_STS_012
# Saved 1-11.png in ./organized_data_PNG/patient_STS_012
# Saved 1-50.png in ./organized_data_PNG/patient_STS_012
# Saved 1-13.png in ./organized_data_PNG/patient_STS_012
# Saved 1-09.png in ./organized_data_PNG/patient_STS_012
# Saved 1-24.png in ./organized_data_PNG/patient_STS_012
# Saved 1-17.png in ./organized_data_PNG/patient_STS_012
# Saved 1-32.png in ./organized_data_PNG/patient_STS_012
# Saved 1-36.png in ./organized_data_PNG/patient_STS_012
# Saved 1-41.png in ./organized_data_PNG/patient_STS_012
# Saved 1-30.png in ./organized_data_PNG/patient_STS_012
# Saved 1-38.png in ./organized_data_PNG/patient_STS_012
# Saved 1-18.png in ./organized_data_PNG/patient_STS_012
# Saved 1-28.png in ./organized_data_PNG/patient_STS_012
# Saved 1-47.png in ./organized_data_PNG/patient_STS_012
# Saved 1-45.png in ./organized_data_PNG/patient_STS_012
# Saved 1-40.png in ./organized_data_PNG/patient_STS_012
# Saved 1-25.png in ./organized_data_PNG/patient_STS_012
# Saved 1-12.png in ./organized_data_PNG/patient_STS_012
# Saved 1-48.png in ./organized_data_PNG/patient_STS_012
# Saved 1-07.png in ./organized_data_PNG/patient_STS_012
# Saved 1-34.png in ./organized_data_PNG/patient_STS_012
# Saved 1-05.png in ./organized_data_PNG/patient_STS_012
# Saved 1-26.png in ./organized_data_PNG/patient_STS_012
# Saved 1-31.png in ./organized_data_PNG/patient_STS_012
# Saved 1-01.png in ./organized_data_PNG/patient_STS_012
# Saved 1-39.png in ./organized_data_PNG/patient_STS_012
# Saved 1-37.png in ./organized_data_PNG/patient_STS_012
# Saved 1-35.png in ./organized_data_PNG/patient_STS_012

# %%
import torch
import torch.nn as nn
from monai.networks.nets import UNet
from torchvision.models import vit_b_16
import torch.nn.functional as F

class UNet3D(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(UNet3D, self).__init__()
        self.unet = UNet(
            spatial_dims=3,
            in_channels=in_channels,
            out_channels=out_channels,
            channels=(16, 32, 64, 128, 256),
            strides=(2, 2, 2, 2)  # Downsampling
        )

    def forward(self, x):
        return self.unet(x)

# class TransformerModule(nn.Module):
#     def __init__(self):
#         super(TransformerModule, self).__init__()
#         self.transformer = vit_b_16(pretrained=True)  # Vision Transformer

#     def forward(self, x):
#         batch_size, channels, depth, height, width = x.shape
#         x = x.permute(0, 2, 1, 3, 4).reshape(batch_size * depth, channels, height, width)  # Flatten depth
#         x = self.transformer(x)
#         x = x.view(batch_size, depth, -1)
#         return x

class TransformerModule(nn.Module):
    def __init__(self):
        super(TransformerModule, self).__init__()
        self.transformer = vit_b_16(pretrained=True)  # Vision Transformer

    def forward(self, x):
        batch_size, channels, depth, height, width = x.shape

        # Loop through each slice in the depth dimension and resize height and width to 224x224
        resized_slices = []
        for i in range(depth):
            slice_2d = x[:, :, i, :, :]  # Extract each 2D slice (N, C, H, W)

            # Duplicate the grayscale channel to form 3 channels (N, 3, H, W)
            slice_2d = slice_2d.repeat(1, 3, 1, 1)

            # Resize to (224x224) as required by Vision Transformer
            resized_slice = F.interpolate(slice_2d, size=(224, 224), mode='bilinear', align_corners=False)
            resized_slices.append(resized_slice)

        # Stack the resized slices back into a tensor of shape (N, C, D, 224, 224)
        resized_3d = torch.stack(resized_slices, dim=2)

        # Flatten depth to treat each slice as a separate image for the Transformer
        x = resized_3d.permute(0, 2, 1, 3, 4).reshape(batch_size * depth, 3, 224, 224)

        # Apply Vision Transformer
        x = self.transformer(x)

        # Reshape the output back to original batch and depth dimensions
        x = x.view(batch_size, depth, -1)
        return x

class Hybrid3DModel(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(Hybrid3DModel, self).__init__()
        self.unet3d = UNet3D(in_channels, out_channels)
        self.transformer = TransformerModule()
        self.conv_final = nn.Conv3d(in_channels, out_channels, kernel_size=1)

    def forward(self, x):
        # 3D CNN (U-Net) for volumetric feature extraction
        unet_output = self.unet3d(x)

        # Transformer for capturing long-range dependencies
        transformer_output = self.transformer(x)

        # Combine 3D CNN output with Transformer output
        combined = unet_output + transformer_output

        # Final convolution for output prediction
        output = self.conv_final(combined.unsqueeze(1))
        return output

# Instantiate the hybrid model
model = Hybrid3DModel(in_channels=1, out_channels=1)
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ViT_B_16_Weights.IMAGENET1K_V1`. You can also use `weights=ViT_B_16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
from pytorch_msssim import ssim
import torch.optim as optim

# Loss functions
mse_loss = nn.MSELoss()  # Mean Squared Error for pixel-wise comparison

# Optimizer
optimizer = optim.AdamW(model.parameters(), lr=1e-4)  # AdamW optimizer
